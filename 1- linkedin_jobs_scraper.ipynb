# %% [markdown]
# # LinkedIn Jobs Scraper Việt Nam (IT) - Phiên bản Jupyter Notebook
#
# Script này scrape job IT từ LinkedIn Việt Nam sử dụng Voyager API unofficial.
#
# **Cảnh báo**:
# - Đây là unofficial API → LinkedIn có thể block IP/account bất cứ lúc nào.
# - Phải cập nhật `csrf-token` và `li_at` cookie thường xuyên (lấy từ DevTools khi login LinkedIn).
# - Chạy chậm, có sleep để tránh block.
# - Năm 2026: Endpoint có thể thay đổi → kiểm tra Network tab trên browser nếu lỗi.
#
# Chạy từng cell theo thứ tự.

# %%
# Cell 1: Import thư viện
import requests
import json
from urllib.parse import quote
import csv
import time
import datetime
import os
from dotenv import load_dotenv
from concurrent.futures import ThreadPoolExecutor, as_completed

print("Import thành công!")
# Out:
# Import thành công!

# %%
# Cell 2: Cấu hình chính (CHỈNH Ở ĐÂY)

SUMMARY_FILE = "linkedin_job_summaries.jsonl"       # File lưu job đã xử lý thành công
CSV_FILE = "linkedin_jobs_vietnam_it_full.csv"     # File CSV output
COUNT = 100                                        # Số job mỗi trang (max ~100)
MAX_WORKERS = 8                                    # Số luồng song song lấy detail
RETRY_COUNT = 3                                    # Số lần retry khi fail detail

load_dotenv(); 

# Headers & Cookies - BẮT BUỘC CẬP NHẬT THƯỜNG XUYÊN!

headers = {
    "accept": os.getenv("LI_ACCEPT"),
    "csrf-token": os.getenv("LI_CSRF_TOKEN"),
    "referer": os.getenv("LI_REFERER"),
    "user-agent": os.getenv("LI_USER_AGENT"),
    "x-li-lang": os.getenv("LI_LANG"),
    "x-restli-protocol-version": os.getenv("LI_RESTLI_VERSION"),
}

cookies = {
    "li_at": os.getenv("LI_AT"),
    "JSESSIONID": f'"{os.getenv("JSESSIONID")}"',  # LinkedIn BẮT BUỘC có dấu "
}

session = requests.Session()
session.headers.update(headers)
session.cookies.update(cookies)

print("Cấu hình hoàn tất.")
# Out:
# Cấu hình hoàn tất.

# %%
# Cell 3: Load keywords từ file (hoặc mặc định)
def load_keywords(filename="keywords.txt"):
    try:
        with open(filename, "r", encoding="utf-8") as f:
            keywords = [line.strip() for line in f if line.strip()]
        print(f"Đã tải {len(keywords)} từ khóa: {keywords}")
        return keywords
    except FileNotFoundError:
        print("Không tìm thấy 'keywords.txt' → dùng mặc định")
        return ["it", "software engineer", "data analyst", "developer vietnam"]

keywords_list = load_keywords()
print("\nDanh sách keywords:", keywords_list)
# Out:
# Đã tải 229 từ khóa: ['IT', 'Information Technology', 'Công nghệ thông tin', 'CNTT', 'Computer Science', 'CS', 'Software', 'Hardware', 'Firmware', 'System', 'Application', 'Platform', 'Infrastructure', 'Technology', 'Tech', 'Lập trình', 'Lập trình viên', 'Programmer', 'Developer', 'Software Developer', 'Software Engineer', 'Kỹ sư phần mềm', 'Frontend Developer', 'Backend Developer', 'Fullstack Developer', 'Web Developer', 'Mobile Developer', 'Senior Developer', 'Senior Engineer', 'Lead Developer', 'Junior Developer', 'Junior Engineer', 'Fresher IT', 'Intern IT', 'Thực tập sinh IT', 'Entry Level', 'Mid Level', 'Remote IT', 'Hybrid IT', 'Onsite', 'Offshore', 'Nearshore', 'Outsourcing', 'ODC', 'Python', 'Java', 'JavaScript', 'TypeScript', 'PHP', '.NET', 'C#', 'Golang', 'Go', 'Ruby', 'Kotlin', 'Swift', 'C', 'C++', 'Rust', 'Scala', 'Objective-C', 'Shell Script', 'Bash', 'PowerShell', 'SQL', 'NoSQL', 'Database', 'DB', 'RDBMS', 'MySQL', 'PostgreSQL', 'Oracle', 'SQL Server', 'MongoDB', 'Redis', 'Cassandra', 'HBase', 'Elasticsearch', 'Angular', 'Vue', 'Vue.js', 'React', 'ReactJS', 'NodeJS', 'Spring', 'Spring Boot', 'ExpressJS', 'Next.js', 'Nuxt.js', 'React Native', 'Flutter', 'Android', 'Android Developer', 'iOS', 'iOS Developer', 'Data Engineer', 'Big Data Engineer', 'Data Analyst', 'Data Scientist', 'Data Pipeline', 'ETL', 'ELT', 'Batch Processing', 'Stream Processing', 'Apache Spark', 'Apache Flink', 'Apache Kafka', 'Apache Airflow', 'Hadoop', 'HDFS', 'Hive', 'Presto', 'Trino', 'BigQuery', 'Snowflake', 'Redshift', 'AI', 'Artificial Intelligence', 'Machine Learning', 'ML', 'ML Engineer', 'Machine Learning Engineer', 'Deep Learning', 'Deep Learning Engineer', 'Neural Network', 'NLP', 'Computer Vision', 'CV', 'LLM', 'RAG', 'Prompt Engineering', 'Fine-tuning', 'DevOps', 'DevOps Engineer', 'CI/CD', 'Docker', 'Kubernetes', 'K8s', 'Helm', 'Terraform', 'Ansible', 'Cloud', 'Cloud Computing', 'Cloud Engineer', 'AWS', 'Amazon Web Services', 'Azure', 'Microsoft Azure', 'GCP', 'Google Cloud', 'Linux', 'Unix', 'Windows', 'Windows Server', 'System Administrator', 'SysAdmin', 'Network', 'Networking', 'Network Engineer', 'TCP/IP', 'HTTP', 'HTTPS', 'DNS', 'Firewall', 'Load Balancer', 'Reverse Proxy', 'VPN', 'Cybersecurity', 'Cyber Security', 'Security Engineer', 'An toàn thông tin', 'Encryption', 'Authentication', 'Authorization', 'IAM', 'SOC', 'Pentest', 'Ethical Hacking', 'QA', 'QC', 'QA Engineer', 'QC Engineer', 'Tester', 'Manual Tester', 'Automation Tester', 'Software Testing', 'Unit Test', 'Integration Test', 'System Test', 'Regression Test', 'UAT', 'Business Analyst', 'BA', 'IT Business Analyst', 'Requirement', 'User Story', 'BRD', 'FRD', 'Project Manager', 'PM', 'IT Project Manager', 'Product Owner', 'PO', 'Scrum Master', 'Agile Coach', 'Agile', 'Scrum', 'Kanban', 'Waterfall', 'SDLC', 'Sprint', 'Backlog', 'Fintech', 'E-commerce', 'EdTech', 'HealthTech', 'InsurTech', 'PropTech', 'Game Development', 'Game Engineer', 'Blockchain', 'Blockchain Developer', 'IoT', 'IoT Engineer', 'AR', 'VR', 'Metaverse', 'Chuyển đổi số', 'Digital Transformation']
#
# Danh sách keywords: ['IT', 'Information Technology', 'Công nghệ thông tin', 'CNTT', 'Computer Science', 'CS', 'Software', 'Hardware', 'Firmware', 'System', 'Application', 'Platform', 'Infrastructure', 'Technology', 'Tech', 'Lập trình', 'Lập trình viên', 'Programmer', 'Developer', 'Software Developer', 'Software Engineer', 'Kỹ sư phần mềm', 'Frontend Developer', 'Backend Developer', 'Fullstack Developer', 'Web Developer', 'Mobile Developer', 'Senior Developer', 'Senior Engineer', 'Lead Developer', 'Junior Developer', 'Junior Engineer', 'Fresher IT', 'Intern IT', 'Thực tập sinh IT', 'Entry Level', 'Mid Level', 'Remote IT', 'Hybrid IT', 'Onsite', 'Offshore', 'Nearshore', 'Outsourcing', 'ODC', 'Python', 'Java', 'JavaScript', 'TypeScript', 'PHP', '.NET', 'C#', 'Golang', 'Go', 'Ruby', 'Kotlin', 'Swift', 'C', 'C++', 'Rust', 'Scala', 'Objective-C', 'Shell Script', 'Bash', 'PowerShell', 'SQL', 'NoSQL', 'Database', 'DB', 'RDBMS', 'MySQL', 'PostgreSQL', 'Oracle', 'SQL Server', 'MongoDB', 'Redis', 'Cassandra', 'HBase', 'Elasticsearch', 'Angular', 'Vue', 'Vue.js', 'React', 'ReactJS', 'NodeJS', 'Spring', 'Spring Boot', 'ExpressJS', 'Next.js', 'Nuxt.js', 'React Native', 'Flutter', 'Android', 'Android Developer', 'iOS', 'iOS Developer', 'Data Engineer', 'Big Data Engineer', 'Data Analyst', 'Data Scientist', 'Data Pipeline', 'ETL', 'ELT', 'Batch Processing', 'Stream Processing', 'Apache Spark', 'Apache Flink', 'Apache Kafka', 'Apache Airflow', 'Hadoop', 'HDFS', 'Hive', 'Presto', 'Trino', 'BigQuery', 'Snowflake', 'Redshift', 'AI', 'Artificial Intelligence', 'Machine Learning', 'ML', 'ML Engineer', 'Machine Learning Engineer', 'Deep Learning', 'Deep Learning Engineer', 'Neural Network', 'NLP', 'Computer Vision', 'CV', 'LLM', 'RAG', 'Prompt Engineering', 'Fine-tuning', 'DevOps', 'DevOps Engineer', 'CI/CD', 'Docker', 'Kubernetes', 'K8s', 'Helm', 'Terraform', 'Ansible', 'Cloud', 'Cloud Computing', 'Cloud Engineer', 'AWS', 'Amazon Web Services', 'Azure', 'Microsoft Azure', 'GCP', 'Google Cloud', 'Linux', 'Unix', 'Windows', 'Windows Server', 'System Administrator', 'SysAdmin', 'Network', 'Networking', 'Network Engineer', 'TCP/IP', 'HTTP', 'HTTPS', 'DNS', 'Firewall', 'Load Balancer', 'Reverse Proxy', 'VPN', 'Cybersecurity', 'Cyber Security', 'Security Engineer', 'An toàn thông tin', 'Encryption', 'Authentication', 'Authorization', 'IAM', 'SOC', 'Pentest', 'Ethical Hacking', 'QA', 'QC', 'QA Engineer', 'QC Engineer', 'Tester', 'Manual Tester', 'Automation Tester', 'Software Testing', 'Unit Test', 'Integration Test', 'System Test', 'Regression Test', 'UAT', 'Business Analyst', 'BA', 'IT Business Analyst', 'Requirement', 'User Story', 'BRD', 'FRD', 'Project Manager', 'PM', 'IT Project Manager', 'Product Owner', 'PO', 'Scrum Master', 'Agile Coach', 'Agile', 'Scrum', 'Kanban', 'Waterfall', 'SDLC', 'Sprint', 'Backlog', 'Fintech', 'E-commerce', 'EdTech', 'HealthTech', 'InsurTech', 'PropTech', 'Game Development', 'Game Engineer', 'Blockchain', 'Blockchain Developer', 'IoT', 'IoT Engineer', 'AR', 'VR', 'Metaverse', 'Chuyển đổi số', 'Digital Transformation']

# %%
# Cell 4: Load job đã xử lý trước đó (tránh duplicate)
def load_existing_summaries():
    if not os.path.exists(SUMMARY_FILE):
        return set()
    existing_ids = set()
    with open(SUMMARY_FILE, "r", encoding="utf-8") as f:
        for i, line in enumerate(f):
            if (i + 1) % 500 == 0:
                print(f"   Loading summaries cũ: {i+1} dòng...")
            if line.strip():
                try:
                    entry = json.loads(line)
                    existing_ids.add(entry['job_id'])
                except:
                    pass
    print(f"Đã load {len(existing_ids)} job đã xử lý trước đó.")
    return existing_ids

processed_job_ids = load_existing_summaries()
seen_job_ids = processed_job_ids.copy()
# Out:
#    Loading summaries cũ: 500 dòng...
#    Loading summaries cũ: 1000 dòng...
#    Loading summaries cũ: 1500 dòng...
#    Loading summaries cũ: 2000 dòng...
#    Loading summaries cũ: 2500 dòng...
#    Loading summaries cũ: 3000 dòng...
#    Loading summaries cũ: 3500 dòng...
#    Loading summaries cũ: 4000 dòng...
#    Loading summaries cũ: 4500 dòng...
#    Loading summaries cũ: 5000 dòng...
#    Loading summaries cũ: 5500 dòng...
#    Loading summaries cũ: 6000 dòng...
#    Loading summaries cũ: 6500 dòng...
#    Loading summaries cũ: 7000 dòng...
#    Loading summaries cũ: 7500 dòng...
#    Loading summaries cũ: 8000 dòng...
#    Loading summaries cũ: 8500 dòng...
#    Loading summaries cũ: 9000 dòng...
#    Loading summaries cũ: 9500 dòng...
#    Loading summaries cũ: 10000 dòng...
# Đã load 10093 job đã xử lý trước đó.

# %%
# Cell 5: Hàm fetch danh sách job (pagination)
base_url = "https://www.linkedin.com/voyager/api/voyagerJobsDashJobCards"

def fetch_job_list(keyword, seen_job_ids):
    query_string_base = (
        f"decorationId=com.linkedin.voyager.dash.deco.jobs.search.JobSearchCardsCollectionLite-88"
        f"&count={COUNT}"
        f"&q=jobSearch"
        f"&query=(origin:SWITCH_SEARCH_VERTICAL,keywords:{keyword},spellCorrectionEnabled:true)"
        f"&servedEventEnabled=false"
    )

    new_jobs = []
    start = 0
    total = None
    page = 1

    print(f"[{keyword.upper()}] Bắt đầu tìm kiếm...")

    while total is None or start < total:
        print(f"   Trang {page} (start={start})...", end=" ")
        url = f"{base_url}?{query_string_base}&start={start}"
        try:
            response = session.get(url, timeout=30)
            if response.status_code != 200:
                print(f"HTTP {response.status_code}")
                break
            data = response.json()
        except Exception as e:
            print(f"Lỗi: {e}")
            break

        included = data.get('included', [])
        if total is None:
            total = data.get('data', {}).get('paging', {}).get('total', 0)
            print(f"→ Tổng: {total}")

        jobs_found = 0
        for item in included:
            if (item.get('$type') == 'com.linkedin.voyager.dash.jobs.JobPosting' and
                item.get('entityUrn', '').startswith('urn:li:fsd_jobPosting:')):
                job_id = item['entityUrn'].split(':')[-1]
                if job_id not in seen_job_ids:
                    seen_job_ids.add(job_id)
                    new_jobs.append(item)
                    jobs_found += 1

        print(f"+{jobs_found} job mới")
        if jobs_found == 0 and start > 0:
            break

        start += COUNT
        page += 1
        time.sleep(1)

    print(f"[{keyword.upper()}] Hoàn thành: +{len(new_jobs)} job mới\n")
    return new_jobs

# %%
# Cell 6: Hàm fetch chi tiết job (có retry)
def fetch_job_detail(job_id):
    url_temp = "https://www.linkedin.com/voyager/api/graphql"
    urn_raw = f"urn:li:fsd_jobPosting:{job_id}"
    urn_encoded = quote(urn_raw, safe="")
    variables = f"(jobPostingUrn:{urn_encoded})"
    query_id = "voyagerJobsDashJobPostings.891aed7916d7453a37e4bbf5f1f60de4"  # Có thể thay đổi theo thời gian
    url = f"{url_temp}?variables={variables}&queryId={query_id}"

    for attempt in range(RETRY_COUNT):
        try:
            response = session.get(url, timeout=20)
            if response.status_code != 200:
                if attempt == RETRY_COUNT - 1:
                    return None, None
                time.sleep(1)
                continue
            data = response.json()
            included = data.get('included', [])
            for item in included:
                if item.get('$type') == 'com.linkedin.voyager.dash.jobs.JobPosting':
                    return item, included
            return None, None
        except Exception:
            if attempt == RETRY_COUNT - 1:
                return None, None
            time.sleep(2 ** attempt)
    return None, None

# %%
# Cell 7: Hàm extract thông tin job
def extract_job_info(job_detail, included=None):
    if not job_detail:
        return None

    def resolve_urn(urn, target_type):
        if not urn or not included:
            return None
        for item in included:
            if item.get('entityUrn') == urn and item.get('$type') == target_type:
                return item
        return None

    job_id = job_detail.get('entityUrn', '').split(':')[-1]
    job_title = job_detail.get('title', '')
    company_name = job_detail.get('companyDetails', {}).get('name')

    location = None
    loc_urn = job_detail.get('*location')
    if loc_urn and isinstance(loc_urn, str):
        geo = resolve_urn(loc_urn, 'com.linkedin.voyager.dash.common.Geo')
        if geo:
            location = geo.get('defaultLocalizedName') or geo.get('abbreviatedLocalizedName')
    if not location:
        location = job_detail.get('formattedLocation')

    description = job_detail.get('description', {}).get('text', '')

    posting_date = None
    if job_detail.get('listedAt'):
        try:
            posting_date = datetime.datetime.fromtimestamp(job_detail['listedAt'] / 1000).strftime('%Y-%m-%d')
        except:
            pass

    # Các field khác tương tự...
    job_url = f"https://www.linkedin.com/jobs/view/{job_id}"

    return {
        'job_id': job_id,
        'job_title': job_title,
        'company': company_name,
        'location': location,
        'description': description,
        'posting_date': posting_date,
        'job_url': job_url,
        'crawled_at': datetime.datetime.now().isoformat(),
        # Thêm các field khác nếu cần
    }

# %%
# Cell 8: CHẠY SCRAPING CHÍNH (chạy cell này cuối cùng)

all_new_jobs = []

for idx, kw in enumerate(keywords_list, 1):
    print(f"[{idx}/{len(keywords_list)}] Từ khóa: '{kw}'")
    new_jobs = fetch_job_list(kw, seen_job_ids)
    all_new_jobs.extend(new_jobs)

if not all_new_jobs:
    print("Không có job mới nào. Kết thúc.")
else:
    print(f"\nTổng {len(all_new_jobs)} job mới cần lấy detail.\n")

    file_exists = os.path.exists(CSV_FILE)
    with open(CSV_FILE, 'a', newline='', encoding='utf-8-sig') as csvfile:
        fieldnames = ['job_id', 'job_title', 'company', 'location', 'description',
                      'posting_date', 'job_url', 'crawled_at']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        if not file_exists or os.stat(CSV_FILE).st_size == 0:
            writer.writeheader()

        success = 0
        failed = 0

        with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
            futures = {executor.submit(fetch_job_detail, job['entityUrn'].split(':')[-1]): job for job in all_new_jobs}

            processed = 0
            total = len(futures)
            for future in as_completed(futures):
                processed += 1
                job = futures[future]
                job_id = job['entityUrn'].split(':')[-1]
                title = job.get('title', 'No title')

                job_detail, included = future.result()
                source = job_detail or job
                info = extract_job_info(source, included=included)

                if info:
                    writer.writerow(info)
                    csvfile.flush()

                    # Lưu summary
                    entry = {
                        "job_id": job_id,
                        "title": job.get('title'),
                        "entityUrn": job['entityUrn'],
                        "crawled_at": datetime.datetime.now().isoformat(),
                    }
                    with open(SUMMARY_FILE, "a", encoding="utf-8") as f:
                        f.write(json.dumps(entry, ensure_ascii=False) + "\n")

                    success += 1
                    print(f"[{processed}/{total}] [OK] {job_id} - {title}")
                else:
                    failed += 1
                    print(f"[{processed}/{total}] [FAIL] {job_id} - {title}")

                time.sleep(0.25)

    print("\nHOÀN THÀNH!")
    print(f"Thành công: {success} | Fail: {failed} | File: {CSV_FILE}")
# Out:
# [1/229] Từ khóa: 'IT'
# [IT] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)...
# → Tổng: 795
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [IT] Hoàn thành: +0 job mới
#
# [2/229] Từ khóa: 'Information Technology'
# [INFORMATION TECHNOLOGY] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 164
# +0 job mới
#    Trang 2 (start=100)... +1 job mới
# [INFORMATION TECHNOLOGY] Hoàn thành: +1 job mới
#
# [3/229] Từ khóa: 'Công nghệ thông tin'
# [CÔNG NGHỆ THÔNG TIN] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2413
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [CÔNG NGHỆ THÔNG TIN] Hoàn thành: +0 job mới
#
# [4/229] Từ khóa: 'CNTT'
# [CNTT] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 19
# +0 job mới
# [CNTT] Hoàn thành: +0 job mới
#
# [5/229] Từ khóa: 'Computer Science'
# [COMPUTER SCIENCE] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 3180
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [COMPUTER SCIENCE] Hoàn thành: +0 job mới
#
# [6/229] Từ khóa: 'CS'
# [CS] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2171
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [CS] Hoàn thành: +0 job mới
#
# [7/229] Từ khóa: 'Software'
# [SOFTWARE] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2399
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [SOFTWARE] Hoàn thành: +0 job mới
#
# [8/229] Từ khóa: 'Hardware'
# [HARDWARE] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2386
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [HARDWARE] Hoàn thành: +0 job mới
#
# [9/229] Từ khóa: 'Firmware'
# [FIRMWARE] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2186
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [FIRMWARE] Hoàn thành: +0 job mới
#
# [10/229] Từ khóa: 'System'
# [SYSTEM] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2501
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [SYSTEM] Hoàn thành: +0 job mới
#
# [11/229] Từ khóa: 'Application'
# [APPLICATION] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2449
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [APPLICATION] Hoàn thành: +0 job mới
#
# [12/229] Từ khóa: 'Platform'
# [PLATFORM] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 117
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [PLATFORM] Hoàn thành: +0 job mới
#
# [13/229] Từ khóa: 'Infrastructure'
# [INFRASTRUCTURE] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 3021
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [INFRASTRUCTURE] Hoàn thành: +0 job mới
#
# [14/229] Từ khóa: 'Technology'
# [TECHNOLOGY] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2438
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [TECHNOLOGY] Hoàn thành: +0 job mới
#
# [15/229] Từ khóa: 'Tech'
# [TECH] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2400
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [TECH] Hoàn thành: +0 job mới
#
# [16/229] Từ khóa: 'Lập trình'
# [LẬP TRÌNH] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2421
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [LẬP TRÌNH] Hoàn thành: +0 job mới
#
# [17/229] Từ khóa: 'Lập trình viên'
# [LẬP TRÌNH VIÊN] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2395
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [LẬP TRÌNH VIÊN] Hoàn thành: +0 job mới
#
# [18/229] Từ khóa: 'Programmer'
# [PROGRAMMER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1976
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [PROGRAMMER] Hoàn thành: +0 job mới
#
# [19/229] Từ khóa: 'Developer'
# [DEVELOPER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2125
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [DEVELOPER] Hoàn thành: +0 job mới
#
# [20/229] Từ khóa: 'Software Developer'
# [SOFTWARE DEVELOPER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1993
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [SOFTWARE DEVELOPER] Hoàn thành: +0 job mới
#
# [21/229] Từ khóa: 'Software Engineer'
# [SOFTWARE ENGINEER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2024
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [SOFTWARE ENGINEER] Hoàn thành: +0 job mới
#
# [22/229] Từ khóa: 'Kỹ sư phần mềm'
# [KỸ SƯ PHẦN MỀM] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2348
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [KỸ SƯ PHẦN MỀM] Hoàn thành: +0 job mới
#
# [23/229] Từ khóa: 'Frontend Developer'
# [FRONTEND DEVELOPER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1146
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [FRONTEND DEVELOPER] Hoàn thành: +0 job mới
#
# [24/229] Từ khóa: 'Backend Developer'
# [BACKEND DEVELOPER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1166
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [BACKEND DEVELOPER] Hoàn thành: +0 job mới
#
# [25/229] Từ khóa: 'Fullstack Developer'
# [FULLSTACK DEVELOPER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1170
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [FULLSTACK DEVELOPER] Hoàn thành: +0 job mới
#
# [26/229] Từ khóa: 'Web Developer'
# [WEB DEVELOPER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1153
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [WEB DEVELOPER] Hoàn thành: +0 job mới
#
# [27/229] Từ khóa: 'Mobile Developer'
# [MOBILE DEVELOPER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1122
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [MOBILE DEVELOPER] Hoàn thành: +0 job mới
#
# [28/229] Từ khóa: 'Senior Developer'
# [SENIOR DEVELOPER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2039
# +0 job mới
#    Trang 2 (start=100)... +1 job mới
#    Trang 3 (start=200)... +1 job mới
#    Trang 4 (start=300)... +0 job mới
# [SENIOR DEVELOPER] Hoàn thành: +2 job mới
#
# [29/229] Từ khóa: 'Senior Engineer'
# [SENIOR ENGINEER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2245
# +1 job mới
#    Trang 2 (start=100)... +0 job mới
# [SENIOR ENGINEER] Hoàn thành: +1 job mới
#
# [30/229] Từ khóa: 'Lead Developer'
# [LEAD DEVELOPER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2123
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [LEAD DEVELOPER] Hoàn thành: +0 job mới
#
# [31/229] Từ khóa: 'Junior Developer'
# [JUNIOR DEVELOPER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2201
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [JUNIOR DEVELOPER] Hoàn thành: +0 job mới
#
# [32/229] Từ khóa: 'Junior Engineer'
# [JUNIOR ENGINEER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2214
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [JUNIOR ENGINEER] Hoàn thành: +0 job mới
#
# [33/229] Từ khóa: 'Fresher IT'
# [FRESHER IT] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 151
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [FRESHER IT] Hoàn thành: +0 job mới
#
# [34/229] Từ khóa: 'Intern IT'
# [INTERN IT] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 504
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [INTERN IT] Hoàn thành: +0 job mới
#
# [35/229] Từ khóa: 'Thực tập sinh IT'
# [THỰC TẬP SINH IT] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 107
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [THỰC TẬP SINH IT] Hoàn thành: +0 job mới
#
# [36/229] Từ khóa: 'Entry Level'
# [ENTRY LEVEL] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2404
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [ENTRY LEVEL] Hoàn thành: +0 job mới
#
# [37/229] Từ khóa: 'Mid Level'
# [MID LEVEL] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2483
# +1 job mới
#    Trang 2 (start=100)... +0 job mới
# [MID LEVEL] Hoàn thành: +1 job mới
#
# [38/229] Từ khóa: 'Remote IT'
# [REMOTE IT] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 103
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [REMOTE IT] Hoàn thành: +0 job mới
#
# [39/229] Từ khóa: 'Hybrid IT'
# [HYBRID IT] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 573
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [HYBRID IT] Hoàn thành: +0 job mới
#
# [40/229] Từ khóa: 'Onsite'
# [ONSITE] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2424
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [ONSITE] Hoàn thành: +0 job mới
#
# [41/229] Từ khóa: 'Offshore'
# [OFFSHORE] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2
# +0 job mới
# [OFFSHORE] Hoàn thành: +0 job mới
#
# [42/229] Từ khóa: 'Nearshore'
# [NEARSHORE] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 0
# +0 job mới
# [NEARSHORE] Hoàn thành: +0 job mới
#
# [43/229] Từ khóa: 'Outsourcing'
# [OUTSOURCING] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2431
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [OUTSOURCING] Hoàn thành: +0 job mới
#
# [44/229] Từ khóa: 'ODC'
# [ODC] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 0
# +0 job mới
# [ODC] Hoàn thành: +0 job mới
#
# [45/229] Từ khóa: 'Python'
# [PYTHON] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 4838
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [PYTHON] Hoàn thành: +0 job mới
#
# [46/229] Từ khóa: 'Java'
# [JAVA] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 4531
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [JAVA] Hoàn thành: +0 job mới
#
# [47/229] Từ khóa: 'JavaScript'
# [JAVASCRIPT] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 4577
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [JAVASCRIPT] Hoàn thành: +0 job mới
#
# [48/229] Từ khóa: 'TypeScript'
# [TYPESCRIPT] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1683
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [TYPESCRIPT] Hoàn thành: +0 job mới
#
# [49/229] Từ khóa: 'PHP'
# [PHP] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2239
# +0 job mới
#    Trang 2 (start=100)... +1 job mới
#    Trang 3 (start=200)... +0 job mới
# [PHP] Hoàn thành: +1 job mới
#
# [50/229] Từ khóa: '.NET'
# [.NET] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2139
# +0 job mới
#    Trang 2 (start=100)... +1 job mới
#    Trang 3 (start=200)... +0 job mới
# [.NET] Hoàn thành: +1 job mới
#
# [51/229] Từ khóa: 'C#'
# [C#] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... HTTP 400
# [C#] Hoàn thành: +0 job mới
#
# [52/229] Từ khóa: 'Golang'
# [GOLANG] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2289
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [GOLANG] Hoàn thành: +0 job mới
#
# [53/229] Từ khóa: 'Go'
# [GO] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 37
# +0 job mới
# [GO] Hoàn thành: +0 job mới
#
# [54/229] Từ khóa: 'Ruby'
# [RUBY] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 26
# +0 job mới
# [RUBY] Hoàn thành: +0 job mới
#
# [55/229] Từ khóa: 'Kotlin'
# [KOTLIN] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1856
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [KOTLIN] Hoàn thành: +0 job mới
#
# [56/229] Từ khóa: 'Swift'
# [SWIFT] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 6
# +0 job mới
# [SWIFT] Hoàn thành: +0 job mới
#
# [57/229] Từ khóa: 'C'
# [C] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2300
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [C] Hoàn thành: +0 job mới
#
# [58/229] Từ khóa: 'C++'
# [C++] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2936
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [C++] Hoàn thành: +0 job mới
#
# [59/229] Từ khóa: 'Rust'
# [RUST] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 7
# +0 job mới
# [RUST] Hoàn thành: +0 job mới
#
# [60/229] Từ khóa: 'Scala'
# [SCALA] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2217
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [SCALA] Hoàn thành: +0 job mới
#
# [61/229] Từ khóa: 'Objective-C'
# [OBJECTIVE-C] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2335
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [OBJECTIVE-C] Hoàn thành: +0 job mới
#
# [62/229] Từ khóa: 'Shell Script'
# [SHELL SCRIPT] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1228
# +0 job mới
#    Trang 2 (start=100)... +3 job mới
#    Trang 3 (start=200)... +0 job mới
# [SHELL SCRIPT] Hoàn thành: +3 job mới
#
# [63/229] Từ khóa: 'Bash'
# [BASH] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2352
# +0 job mới
#    Trang 2 (start=100)... +1 job mới
#    Trang 3 (start=200)... +0 job mới
# [BASH] Hoàn thành: +1 job mới
#
# [64/229] Từ khóa: 'PowerShell'
# [POWERSHELL] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2133
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [POWERSHELL] Hoàn thành: +0 job mới
#
# [65/229] Từ khóa: 'SQL'
# [SQL] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 4343
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [SQL] Hoàn thành: +0 job mới
#
# [66/229] Từ khóa: 'NoSQL'
# [NOSQL] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2317
# +0 job mới
#    Trang 2 (start=100)... +1 job mới
#    Trang 3 (start=200)... +0 job mới
# [NOSQL] Hoàn thành: +1 job mới
#
# [67/229] Từ khóa: 'Database'
# [DATABASE] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 3059
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [DATABASE] Hoàn thành: +0 job mới
#
# [68/229] Từ khóa: 'DB'
# [DB] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 3
# +0 job mới
# [DB] Hoàn thành: +0 job mới
#
# [69/229] Từ khóa: 'RDBMS'
# [RDBMS] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2315
# +1 job mới
#    Trang 2 (start=100)... +0 job mới
# [RDBMS] Hoàn thành: +1 job mới
#
# [70/229] Từ khóa: 'MySQL'
# [MYSQL] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2393
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [MYSQL] Hoàn thành: +0 job mới
#
# [71/229] Từ khóa: 'PostgreSQL'
# [POSTGRESQL] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1995
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [POSTGRESQL] Hoàn thành: +0 job mới
#
# [72/229] Từ khóa: 'Oracle'
# [ORACLE] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 8
# +0 job mới
# [ORACLE] Hoàn thành: +0 job mới
#
# [73/229] Từ khóa: 'SQL Server'
# [SQL SERVER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2540
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [SQL SERVER] Hoàn thành: +0 job mới
#
# [74/229] Từ khóa: 'MongoDB'
# [MONGODB] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2285
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [MONGODB] Hoàn thành: +0 job mới
#
# [75/229] Từ khóa: 'Redis'
# [REDIS] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2290
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [REDIS] Hoàn thành: +0 job mới
#
# [76/229] Từ khóa: 'Cassandra'
# [CASSANDRA] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 0
# +0 job mới
# [CASSANDRA] Hoàn thành: +0 job mới
#
# [77/229] Từ khóa: 'HBase'
# [HBASE] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2037
# +2 job mới
#    Trang 2 (start=100)... +0 job mới
# [HBASE] Hoàn thành: +2 job mới
#
# [78/229] Từ khóa: 'Elasticsearch'
# [ELASTICSEARCH] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2044
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [ELASTICSEARCH] Hoàn thành: +0 job mới
#
# [79/229] Từ khóa: 'Angular'
# [ANGULAR] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1965
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [ANGULAR] Hoàn thành: +0 job mới
#
# [80/229] Từ khóa: 'Vue'
# [VUE] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 22
# +0 job mới
# [VUE] Hoàn thành: +0 job mới
#
# [81/229] Từ khóa: 'Vue.js'
# [VUE.JS] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1689
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [VUE.JS] Hoàn thành: +0 job mới
#
# [82/229] Từ khóa: 'React'
# [REACT] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2077
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [REACT] Hoàn thành: +0 job mới
#
# [83/229] Từ khóa: 'ReactJS'
# [REACTJS] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2011
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [REACTJS] Hoàn thành: +0 job mới
#
# [84/229] Từ khóa: 'NodeJS'
# [NODEJS] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1988
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [NODEJS] Hoàn thành: +0 job mới
#
# [85/229] Từ khóa: 'Spring'
# [SPRING] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 13
# +0 job mới
# [SPRING] Hoàn thành: +0 job mới
#
# [86/229] Từ khóa: 'Spring Boot'
# [SPRING BOOT] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2019
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [SPRING BOOT] Hoàn thành: +0 job mới
#
# [87/229] Từ khóa: 'ExpressJS'
# [EXPRESSJS] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2211
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [EXPRESSJS] Hoàn thành: +0 job mới
#
# [88/229] Từ khóa: 'Next.js'
# [NEXT.JS] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1825
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [NEXT.JS] Hoàn thành: +0 job mới
#
# [89/229] Từ khóa: 'Nuxt.js'
# [NUXT.JS] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1814
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [NUXT.JS] Hoàn thành: +0 job mới
#
# [90/229] Từ khóa: 'React Native'
# [REACT NATIVE] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1978
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [REACT NATIVE] Hoàn thành: +0 job mới
#
# [91/229] Từ khóa: 'Flutter'
# [FLUTTER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 14
# +0 job mới
# [FLUTTER] Hoàn thành: +0 job mới
#
# [92/229] Từ khóa: 'Android'
# [ANDROID] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2189
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [ANDROID] Hoàn thành: +0 job mới
#
# [93/229] Từ khóa: 'Android Developer'
# [ANDROID DEVELOPER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1134
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [ANDROID DEVELOPER] Hoàn thành: +0 job mới
#
# [94/229] Từ khóa: 'iOS'
# [IOS] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2138
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [IOS] Hoàn thành: +0 job mới
#
# [95/229] Từ khóa: 'iOS Developer'
# [IOS DEVELOPER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1052
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [IOS DEVELOPER] Hoàn thành: +0 job mới
#
# [96/229] Từ khóa: 'Data Engineer'
# [DATA ENGINEER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1047
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [DATA ENGINEER] Hoàn thành: +0 job mới
#
# [97/229] Từ khóa: 'Big Data Engineer'
# [BIG DATA ENGINEER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1020
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [BIG DATA ENGINEER] Hoàn thành: +0 job mới
#
# [98/229] Từ khóa: 'Data Analyst'
# [DATA ANALYST] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 222
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [DATA ANALYST] Hoàn thành: +0 job mới
#
# [99/229] Từ khóa: 'Data Scientist'
# [DATA SCIENTIST] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2262
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [DATA SCIENTIST] Hoàn thành: +0 job mới
#
# [100/229] Từ khóa: 'Data Pipeline'
# [DATA PIPELINE] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2277
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [DATA PIPELINE] Hoàn thành: +0 job mới
#
# [101/229] Từ khóa: 'ETL'
# [ETL] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2402
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [ETL] Hoàn thành: +0 job mới
#
# [102/229] Từ khóa: 'ELT'
# [ELT] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 0
# +0 job mới
# [ELT] Hoàn thành: +0 job mới
#
# [103/229] Từ khóa: 'Batch Processing'
# [BATCH PROCESSING] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2554
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [BATCH PROCESSING] Hoàn thành: +0 job mới
#
# [104/229] Từ khóa: 'Stream Processing'
# [STREAM PROCESSING] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2311
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [STREAM PROCESSING] Hoàn thành: +0 job mới
#
# [105/229] Từ khóa: 'Apache Spark'
# [APACHE SPARK] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1958
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [APACHE SPARK] Hoàn thành: +0 job mới
#
# [106/229] Từ khóa: 'Apache Flink'
# [APACHE FLINK] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2210
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [APACHE FLINK] Hoàn thành: +0 job mới
#
# [107/229] Từ khóa: 'Apache Kafka'
# [APACHE KAFKA] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1991
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [APACHE KAFKA] Hoàn thành: +0 job mới
#
# [108/229] Từ khóa: 'Apache Airflow'
# [APACHE AIRFLOW] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2163
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [APACHE AIRFLOW] Hoàn thành: +0 job mới
#
# [109/229] Từ khóa: 'Hadoop'
# [HADOOP] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1736
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [HADOOP] Hoàn thành: +0 job mới
#
# [110/229] Từ khóa: 'HDFS'
# [HDFS] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1980
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [HDFS] Hoàn thành: +0 job mới
#
# [111/229] Từ khóa: 'Hive'
# [HIVE] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2
# +0 job mới
# [HIVE] Hoàn thành: +0 job mới
#
# [112/229] Từ khóa: 'Presto'
# [PRESTO] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 0
# +0 job mới
# [PRESTO] Hoàn thành: +0 job mới
#
# [113/229] Từ khóa: 'Trino'
# [TRINO] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2427
# +0 job mới
#    Trang 2 (start=100)... +1 job mới
#    Trang 3 (start=200)... +1 job mới
#    Trang 4 (start=300)... +0 job mới
# [TRINO] Hoàn thành: +2 job mới
#
# [114/229] Từ khóa: 'BigQuery'
# [BIGQUERY] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2324
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [BIGQUERY] Hoàn thành: +0 job mới
#
# [115/229] Từ khóa: 'Snowflake'
# [SNOWFLAKE] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1
# +0 job mới
# [SNOWFLAKE] Hoàn thành: +0 job mới
#
# [116/229] Từ khóa: 'Redshift'
# [REDSHIFT] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2489
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [REDSHIFT] Hoàn thành: +0 job mới
#
# [117/229] Từ khóa: 'AI'
# [AI] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 3603
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [AI] Hoàn thành: +0 job mới
#
# [118/229] Từ khóa: 'Artificial Intelligence'
# [ARTIFICIAL INTELLIGENCE] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 3762
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [ARTIFICIAL INTELLIGENCE] Hoàn thành: +0 job mới
#
# [119/229] Từ khóa: 'Machine Learning'
# [MACHINE LEARNING] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2606
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [MACHINE LEARNING] Hoàn thành: +0 job mới
#
# [120/229] Từ khóa: 'ML'
# [ML] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 17
# +0 job mới
# [ML] Hoàn thành: +0 job mới
#
# [121/229] Từ khóa: 'ML Engineer'
# [ML ENGINEER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 991
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [ML ENGINEER] Hoàn thành: +0 job mới
#
# [122/229] Từ khóa: 'Machine Learning Engineer'
# [MACHINE LEARNING ENGINEER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1062
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [MACHINE LEARNING ENGINEER] Hoàn thành: +0 job mới
#
# [123/229] Từ khóa: 'Deep Learning'
# [DEEP LEARNING] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2247
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [DEEP LEARNING] Hoàn thành: +0 job mới
#
# [124/229] Từ khóa: 'Deep Learning Engineer'
# [DEEP LEARNING ENGINEER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2028
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [DEEP LEARNING ENGINEER] Hoàn thành: +0 job mới
#
# [125/229] Từ khóa: 'Neural Network'
# [NEURAL NETWORK] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1327
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [NEURAL NETWORK] Hoàn thành: +0 job mới
#
# [126/229] Từ khóa: 'NLP'
# [NLP] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2252
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [NLP] Hoàn thành: +0 job mới
#
# [127/229] Từ khóa: 'Computer Vision'
# [COMPUTER VISION] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2112
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [COMPUTER VISION] Hoàn thành: +0 job mới
#
# [128/229] Từ khóa: 'CV'
# [CV] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 27
# +0 job mới
# [CV] Hoàn thành: +0 job mới
#
# [129/229] Từ khóa: 'LLM'
# [LLM] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2446
# +2 job mới
#    Trang 2 (start=100)... +0 job mới
# [LLM] Hoàn thành: +2 job mới
#
# [130/229] Từ khóa: 'RAG'
# [RAG] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 0
# +0 job mới
# [RAG] Hoàn thành: +0 job mới
#
# [131/229] Từ khóa: 'Prompt Engineering'
# [PROMPT ENGINEERING] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 0
# +0 job mới
# [PROMPT ENGINEERING] Hoàn thành: +0 job mới
#
# [132/229] Từ khóa: 'Fine-tuning'
# [FINE-TUNING] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2434
# +1 job mới
#    Trang 2 (start=100)... +0 job mới
# [FINE-TUNING] Hoàn thành: +1 job mới
#
# [133/229] Từ khóa: 'DevOps'
# [DEVOPS] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2316
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [DEVOPS] Hoàn thành: +0 job mới
#
# [134/229] Từ khóa: 'DevOps Engineer'
# [DEVOPS ENGINEER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1084
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [DEVOPS ENGINEER] Hoàn thành: +0 job mới
#
# [135/229] Từ khóa: 'CI/CD'
# [CI/CD] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2502
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [CI/CD] Hoàn thành: +0 job mới
#
# [136/229] Từ khóa: 'Docker'
# [DOCKER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 0
# +0 job mới
# [DOCKER] Hoàn thành: +0 job mới
#
# [137/229] Từ khóa: 'Kubernetes'
# [KUBERNETES] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2222
# +0 job mới
#    Trang 2 (start=100)... +1 job mới
#    Trang 3 (start=200)... +0 job mới
# [KUBERNETES] Hoàn thành: +1 job mới
#
# [138/229] Từ khóa: 'K8s'
# [K8S] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 3
# +0 job mới
# [K8S] Hoàn thành: +0 job mới
#
# [139/229] Từ khóa: 'Helm'
# [HELM] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 0
# +0 job mới
# [HELM] Hoàn thành: +0 job mới
#
# [140/229] Từ khóa: 'Terraform'
# [TERRAFORM] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2273
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [TERRAFORM] Hoàn thành: +0 job mới
#
# [141/229] Từ khóa: 'Ansible'
# [ANSIBLE] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2284
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [ANSIBLE] Hoàn thành: +0 job mới
#
# [142/229] Từ khóa: 'Cloud'
# [CLOUD] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 3576
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [CLOUD] Hoàn thành: +0 job mới
#
# [143/229] Từ khóa: 'Cloud Computing'
# [CLOUD COMPUTING] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 3679
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [CLOUD COMPUTING] Hoàn thành: +0 job mới
#
# [144/229] Từ khóa: 'Cloud Engineer'
# [CLOUD ENGINEER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1050
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [CLOUD ENGINEER] Hoàn thành: +0 job mới
#
# [145/229] Từ khóa: 'AWS'
# [AWS] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2924
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [AWS] Hoàn thành: +0 job mới
#
# [146/229] Từ khóa: 'Amazon Web Services'
# [AMAZON WEB SERVICES] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 3267
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [AMAZON WEB SERVICES] Hoàn thành: +0 job mới
#
# [147/229] Từ khóa: 'Azure'
# [AZURE] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2604
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [AZURE] Hoàn thành: +0 job mới
#
# [148/229] Từ khóa: 'Microsoft Azure'
# [MICROSOFT AZURE] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2607
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [MICROSOFT AZURE] Hoàn thành: +0 job mới
#
# [149/229] Từ khóa: 'GCP'
# [GCP] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2552
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [GCP] Hoàn thành: +0 job mới
#
# [150/229] Từ khóa: 'Google Cloud'
# [GOOGLE CLOUD] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 28
# +0 job mới
# [GOOGLE CLOUD] Hoàn thành: +0 job mới
#
# [151/229] Từ khóa: 'Linux'
# [LINUX] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2924
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [LINUX] Hoàn thành: +0 job mới
#
# [152/229] Từ khóa: 'Unix'
# [UNIX] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2437
# +1 job mới
#    Trang 2 (start=100)... +2 job mới
#    Trang 3 (start=200)... +0 job mới
# [UNIX] Hoàn thành: +3 job mới
#
# [153/229] Từ khóa: 'Windows'
# [WINDOWS] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2622
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [WINDOWS] Hoàn thành: +0 job mới
#
# [154/229] Từ khóa: 'Windows Server'
# [WINDOWS SERVER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2412
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [WINDOWS SERVER] Hoàn thành: +0 job mới
#
# [155/229] Từ khóa: 'System Administrator'
# [SYSTEM ADMINISTRATOR] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 24
# +0 job mới
# [SYSTEM ADMINISTRATOR] Hoàn thành: +0 job mới
#
# [156/229] Từ khóa: 'SysAdmin'
# [SYSADMIN] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 24
# +0 job mới
# [SYSADMIN] Hoàn thành: +0 job mới
#
# [157/229] Từ khóa: 'Network'
# [NETWORK] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2296
# +0 job mới
#    Trang 2 (start=100)... +1 job mới
#    Trang 3 (start=200)... +0 job mới
# [NETWORK] Hoàn thành: +1 job mới
#
# [158/229] Từ khóa: 'Networking'
# [NETWORKING] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 3042
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [NETWORKING] Hoàn thành: +0 job mới
#
# [159/229] Từ khóa: 'Network Engineer'
# [NETWORK ENGINEER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 28
# +0 job mới
# [NETWORK ENGINEER] Hoàn thành: +0 job mới
#
# [160/229] Từ khóa: 'TCP/IP'
# [TCP/IP] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2407
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [TCP/IP] Hoàn thành: +0 job mới
#
# [161/229] Từ khóa: 'HTTP'
# [HTTP] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2524
# +0 job mới
#    Trang 2 (start=100)... +1 job mới
#    Trang 3 (start=200)... +0 job mới
# [HTTP] Hoàn thành: +1 job mới
#
# [162/229] Từ khóa: 'HTTPS'
# [HTTPS] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2429
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [HTTPS] Hoàn thành: +0 job mới
#
# [163/229] Từ khóa: 'DNS'
# [DNS] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2408
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [DNS] Hoàn thành: +0 job mới
#
# [164/229] Từ khóa: 'Firewall'
# [FIREWALL] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2546
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [FIREWALL] Hoàn thành: +0 job mới
#
# [165/229] Từ khóa: 'Load Balancer'
# [LOAD BALANCER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2433
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [LOAD BALANCER] Hoàn thành: +0 job mới
#
# [166/229] Từ khóa: 'Reverse Proxy'
# [REVERSE PROXY] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2495
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [REVERSE PROXY] Hoàn thành: +0 job mới
#
# [167/229] Từ khóa: 'VPN'
# [VPN] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2392
# +0 job mới
#    Trang 2 (start=100)... +1 job mới
#    Trang 3 (start=200)... +0 job mới
# [VPN] Hoàn thành: +1 job mới
#
# [168/229] Từ khóa: 'Cybersecurity'
# [CYBERSECURITY] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2583
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [CYBERSECURITY] Hoàn thành: +0 job mới
#
# [169/229] Từ khóa: 'Cyber Security'
# [CYBER SECURITY] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 42
# +0 job mới
# [CYBER SECURITY] Hoàn thành: +0 job mới
#
# [170/229] Từ khóa: 'Security Engineer'
# [SECURITY ENGINEER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 877
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [SECURITY ENGINEER] Hoàn thành: +0 job mới
#
# [171/229] Từ khóa: 'An toàn thông tin'
# [AN TOÀN THÔNG TIN] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2523
# +0 job mới
#    Trang 2 (start=100)... +1 job mới
#    Trang 3 (start=200)... +0 job mới
# [AN TOÀN THÔNG TIN] Hoàn thành: +1 job mới
#
# [172/229] Từ khóa: 'Encryption'
# [ENCRYPTION] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2401
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [ENCRYPTION] Hoàn thành: +0 job mới
#
# [173/229] Từ khóa: 'Authentication'
# [AUTHENTICATION] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2555
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [AUTHENTICATION] Hoàn thành: +0 job mới
#
# [174/229] Từ khóa: 'Authorization'
# [AUTHORIZATION] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2474
# +0 job mới
#    Trang 2 (start=100)... +1 job mới
#    Trang 3 (start=200)... +0 job mới
# [AUTHORIZATION] Hoàn thành: +1 job mới
#
# [175/229] Từ khóa: 'IAM'
# [IAM] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 0
# +0 job mới
# [IAM] Hoàn thành: +0 job mới
#
# [176/229] Từ khóa: 'SOC'
# [SOC] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 102
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [SOC] Hoàn thành: +0 job mới
#
# [177/229] Từ khóa: 'Pentest'
# [PENTEST] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1
# +0 job mới
# [PENTEST] Hoàn thành: +0 job mới
#
# [178/229] Từ khóa: 'Ethical Hacking'
# [ETHICAL HACKING] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2262
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [ETHICAL HACKING] Hoàn thành: +0 job mới
#
# [179/229] Từ khóa: 'QA'
# [QA] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1911
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [QA] Hoàn thành: +0 job mới
#
# [180/229] Từ khóa: 'QC'
# [QC] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2478
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [QC] Hoàn thành: +0 job mới
#
# [181/229] Từ khóa: 'QA Engineer'
# [QA ENGINEER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1897
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [QA ENGINEER] Hoàn thành: +0 job mới
#
# [182/229] Từ khóa: 'QC Engineer'
# [QC ENGINEER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2267
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [QC ENGINEER] Hoàn thành: +0 job mới
#
# [183/229] Từ khóa: 'Tester'
# [TESTER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2478
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [TESTER] Hoàn thành: +0 job mới
#
# [184/229] Từ khóa: 'Manual Tester'
# [MANUAL TESTER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2554
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [MANUAL TESTER] Hoàn thành: +0 job mới
#
# [185/229] Từ khóa: 'Automation Tester'
# [AUTOMATION TESTER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 47
# +0 job mới
# [AUTOMATION TESTER] Hoàn thành: +0 job mới
#
# [186/229] Từ khóa: 'Software Testing'
# [SOFTWARE TESTING] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 34
# +0 job mới
# [SOFTWARE TESTING] Hoàn thành: +0 job mới
#
# [187/229] Từ khóa: 'Unit Test'
# [UNIT TEST] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2520
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [UNIT TEST] Hoàn thành: +0 job mới
#
# [188/229] Từ khóa: 'Integration Test'
# [INTEGRATION TEST] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2109
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [INTEGRATION TEST] Hoàn thành: +0 job mới
#
# [189/229] Từ khóa: 'System Test'
# [SYSTEM TEST] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2087
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [SYSTEM TEST] Hoàn thành: +0 job mới
#
# [190/229] Từ khóa: 'Regression Test'
# [REGRESSION TEST] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2459
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [REGRESSION TEST] Hoàn thành: +0 job mới
#
# [191/229] Từ khóa: 'UAT'
# [UAT] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 0
# +0 job mới
# [UAT] Hoàn thành: +0 job mới
#
# [192/229] Từ khóa: 'Business Analyst'
# [BUSINESS ANALYST] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 140
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [BUSINESS ANALYST] Hoàn thành: +0 job mới
#
# [193/229] Từ khóa: 'BA'
# [BA] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 112
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [BA] Hoàn thành: +0 job mới
#
# [194/229] Từ khóa: 'IT Business Analyst'
# [IT BUSINESS ANALYST] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 47
# +0 job mới
# [IT BUSINESS ANALYST] Hoàn thành: +0 job mới
#
# [195/229] Từ khóa: 'Requirement'
# [REQUIREMENT] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2453
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [REQUIREMENT] Hoàn thành: +0 job mới
#
# [196/229] Từ khóa: 'User Story'
# [USER STORY] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2325
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [USER STORY] Hoàn thành: +0 job mới
#
# [197/229] Từ khóa: 'BRD'
# [BRD] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 0
# +0 job mới
# [BRD] Hoàn thành: +0 job mới
#
# [198/229] Từ khóa: 'FRD'
# [FRD] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 0
# +0 job mới
# [FRD] Hoàn thành: +0 job mới
#
# [199/229] Từ khóa: 'Project Manager'
# [PROJECT MANAGER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 273
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [PROJECT MANAGER] Hoàn thành: +0 job mới
#
# [200/229] Từ khóa: 'PM'
# [PM] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 11
# +0 job mới
# [PM] Hoàn thành: +0 job mới
#
# [201/229] Từ khóa: 'IT Project Manager'
# [IT PROJECT MANAGER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 192
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [IT PROJECT MANAGER] Hoàn thành: +0 job mới
#
# [202/229] Từ khóa: 'Product Owner'
# [PRODUCT OWNER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 72
# +1 job mới
# [PRODUCT OWNER] Hoàn thành: +1 job mới
#
# [203/229] Từ khóa: 'PO'
# [PO] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2465
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [PO] Hoàn thành: +0 job mới
#
# [204/229] Từ khóa: 'Scrum Master'
# [SCRUM MASTER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 216
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [SCRUM MASTER] Hoàn thành: +0 job mới
#
# [205/229] Từ khóa: 'Agile Coach'
# [AGILE COACH] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 5
# +0 job mới
# [AGILE COACH] Hoàn thành: +0 job mới
#
# [206/229] Từ khóa: 'Agile'
# [AGILE] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2824
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [AGILE] Hoàn thành: +0 job mới
#
# [207/229] Từ khóa: 'Scrum'
# [SCRUM] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2984
# +1 job mới
#    Trang 2 (start=100)... +0 job mới
# [SCRUM] Hoàn thành: +1 job mới
#
# [208/229] Từ khóa: 'Kanban'
# [KANBAN] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2454
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [KANBAN] Hoàn thành: +0 job mới
#
# [209/229] Từ khóa: 'Waterfall'
# [WATERFALL] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 0
# +0 job mới
# [WATERFALL] Hoàn thành: +0 job mới
#
# [210/229] Từ khóa: 'SDLC'
# [SDLC] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2445
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [SDLC] Hoàn thành: +0 job mới
#
# [211/229] Từ khóa: 'Sprint'
# [SPRINT] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 0
# +0 job mới
# [SPRINT] Hoàn thành: +0 job mới
#
# [212/229] Từ khóa: 'Backlog'
# [BACKLOG] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 8
# +1 job mới
# [BACKLOG] Hoàn thành: +1 job mới
#
# [213/229] Từ khóa: 'Fintech'
# [FINTECH] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2369
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [FINTECH] Hoàn thành: +0 job mới
#
# [214/229] Từ khóa: 'E-commerce'
# [E-COMMERCE] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2786
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [E-COMMERCE] Hoàn thành: +0 job mới
#
# [215/229] Từ khóa: 'EdTech'
# [EDTECH] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 8
# +0 job mới
# [EDTECH] Hoàn thành: +0 job mới
#
# [216/229] Từ khóa: 'HealthTech'
# [HEALTHTECH] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1934
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [HEALTHTECH] Hoàn thành: +0 job mới
#
# [217/229] Từ khóa: 'InsurTech'
# [INSURTECH] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 28
# +0 job mới
# [INSURTECH] Hoàn thành: +0 job mới
#
# [218/229] Từ khóa: 'PropTech'
# [PROPTECH] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 0
# +0 job mới
# [PROPTECH] Hoàn thành: +0 job mới
#
# [219/229] Từ khóa: 'Game Development'
# [GAME DEVELOPMENT] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 742
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [GAME DEVELOPMENT] Hoàn thành: +0 job mới
#
# [220/229] Từ khóa: 'Game Engineer'
# [GAME ENGINEER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1080
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [GAME ENGINEER] Hoàn thành: +0 job mới
#
# [221/229] Từ khóa: 'Blockchain'
# [BLOCKCHAIN] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2348
# +0 job mới
#    Trang 2 (start=100)... +1 job mới
#    Trang 3 (start=200)... +0 job mới
# [BLOCKCHAIN] Hoàn thành: +1 job mới
#
# [222/229] Từ khóa: 'Blockchain Developer'
# [BLOCKCHAIN DEVELOPER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 960
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [BLOCKCHAIN DEVELOPER] Hoàn thành: +0 job mới
#
# [223/229] Từ khóa: 'IoT'
# [IOT] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2419
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [IOT] Hoàn thành: +0 job mới
#
# [224/229] Từ khóa: 'IoT Engineer'
# [IOT ENGINEER] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1016
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [IOT ENGINEER] Hoàn thành: +0 job mới
#
# [225/229] Từ khóa: 'AR'
# [AR] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2624
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [AR] Hoàn thành: +0 job mới
#
# [226/229] Từ khóa: 'VR'
# [VR] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2418
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [VR] Hoàn thành: +0 job mới
#
# [227/229] Từ khóa: 'Metaverse'
# [METAVERSE] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 0
# +0 job mới
# [METAVERSE] Hoàn thành: +0 job mới
#
# [228/229] Từ khóa: 'Chuyển đổi số'
# [CHUYỂN ĐỔI SỐ] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2529
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [CHUYỂN ĐỔI SỐ] Hoàn thành: +0 job mới
#
# [229/229] Từ khóa: 'Digital Transformation'
# [DIGITAL TRANSFORMATION] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 2571
# +0 job mới
#    Trang 2 (start=100)... +0 job mới
# [DIGITAL TRANSFORMATION] Hoàn thành: +0 job mới
#
#
# Tổng 33 job mới cần lấy detail.
#
# [1/33] [OK] 4350999555 - Business Development Manager (Microsoft Cloud-Surestep)
# [2/33] [OK] 4342266266 - Media Search Analyst - Vietnamese (VN) | Fully Remote
# [3/33] [OK] 4291940305 - Human Resources Manager
# [4/33] [OK] 4342906969 - Chief Accountant
# [5/33] [OK] 4328958251 - PreSales Specialist - (Vietnamese speaker relocate to Malaysia)
# [6/33] [OK] 4329816062 - General Accountant
# [7/33] [OK] 4335394685 - Manager, Sourcing Ingredients
# [8/33] [OK] 4329705445 - Key Account Performance Analyst (Affiliate) - Marketing, Shopee
# [9/33] [OK] 4324850747 - Director, Global Sourcing Development, Altra Footwear
# [10/33] [OK] 4342965370 - General Manager (Logistics Industry / Base Salary up to 190million VND)
# [11/33] [OK] 4350915803 - Officer, Purchasing
# [12/33] [OK] 4346916316 - Layout Design, Staff Engineer in HCMC
# [13/33] [OK] 4329615852 - Business Development Manager
# [14/33] [OK] 4205986514 - Account Executive, Influencer Integrated
# [15/33] [OK] 4326214780 - Expert, Risk Mitigation
# [16/33] [OK] 4341721798 - Quality Control Inspector
# [17/33] [OK] 4329658393 - Human Resources Lead
# [18/33] [OK] 4329654981 - NV Khai Báo Thủ Tục Hải Quan (13-15 triệu VNĐ)
# [19/33] [OK] 4298398135 - General Accountant - Vietnam
# [20/33] [OK] 4350750303 - Production Supervisor
# [21/33] [OK] 4346878830 - Chuyên viên Tài chính
# [22/33] [OK] 4296752173 - Kỹ sư Quản trị cơ sở dữ liệu
# [23/33] [OK] 4333174174 - Chuyên Gia Nhân Sự (Phân Tích Dữ Liệu)
# [24/33] [OK] 4329407922 - Giáo viên tiếng Trung
# [25/33] [OK] 4343365020 - Marketing Intern
# [26/33] [OK] 4329398267 - SEA Regional Indies Partnership Manager (Mandarin Speaking) - GBS
# [27/33] [OK] 4319190772 - Expert, Network Development (40000116)
# [28/33] [OK] 4329018914 - Associate Buying Manager (Phone Accessories & Audio)
# [29/33] [OK] 4338425054 - Medical Representative - ETC - Yen Bai & Tuyen Quang
# [30/33] [OK] 4346975589 - UI/UX Designer
# [31/33] [OK] 4342178025 - Product Engineer, Back-end | Credit & Lending domain
# [32/33] [OK] 4335821365 - Affiliate Relationship Manager
# [33/33] [OK] 4264452556 - R&D Manager
#
# HOÀN THÀNH!
# Thành công: 33 | Fail: 0 | File: linkedin_jobs_vietnam_it_full.csv
