# %% [markdown]
# # LinkedIn Jobs Scraper Việt Nam (IT) - Phiên bản Jupyter Notebook
#
# Script này scrape job IT từ LinkedIn Việt Nam sử dụng Voyager API unofficial.
#
# **Cảnh báo**:
# - Đây là unofficial API → LinkedIn có thể block IP/account bất cứ lúc nào.
# - Phải cập nhật `csrf-token` và `li_at` cookie thường xuyên (lấy từ DevTools khi login LinkedIn).
# - Chạy chậm, có sleep để tránh block.
# - Năm 2026: Endpoint có thể thay đổi → kiểm tra Network tab trên browser nếu lỗi.
#
# Chạy từng cell theo thứ tự.

# %%
# Cell 1: Import thư viện
import requests
import json
from urllib.parse import quote
import csv
import time
import datetime
import os
from dotenv import load_dotenv
from concurrent.futures import ThreadPoolExecutor, as_completed

print("Import thành công!")
# Out:
# Import thành công!

# %%
# Cell 2: Cấu hình chính (CHỈNH Ở ĐÂY)

SUMMARY_FILE = "linkedin_job_summaries.jsonl"
CSV_FILE = "linkedin_jobs_vietnam_it_full.csv"
COUNT = 100
MAX_WORKERS = 8
RETRY_COUNT = 3

load_dotenv()

# Headers từ curl mới nhất
headers = {
    "accept": "application/vnd.linkedin.normalized+json+2.1",
    "accept-language": "en-US,en;q=0.9,vi;q=0.8",
    "csrf-token": "ajax:1656999207179305697",
    "priority": "u=1, i",
    "referer": "https://www.linkedin.com/jobs/search/",
    "sec-ch-prefers-color-scheme": "light",
    "sec-ch-ua": '"Not:A-Brand";v="99", "Google Chrome";v="145", "Chromium";v="145"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36",
    "x-li-lang": "vi_VN",
    "x-li-page-instance": "urn:li:page:d_flagship3_search_srp_jobs;77AFEL7YRiWr2ez/0uP6Vw==",
    "x-li-pem-metadata": "Voyager - Careers - Jobs Search=jobs-search-results,Voyager - Careers - Critical - careers-api=jobs-search-results",
    "x-li-prefetch": "1",
    "x-li-track": '{"clientVersion":"1.13.42665","mpVersion":"1.13.42665","osName":"web","timezoneOffset":7,"timezone":"Asia/Saigon","deviceFormFactor":"DESKTOP","mpName":"voyager-web","displayDensity":1.125,"displayWidth":1728,"displayHeight":972}',
    "x-restli-protocol-version": "2.0.0",
}

# ⚠️ QUAN TRỌNG: Tất cả cookies từ curl -b flag
# Cần cập nhật thường xuyên khi LinkedIn yêu cầu!
cookies = {
    "bscookie": 'v=1&202511160954570107781a-c6b2-4727-83a6-e6848d03d807AQHdfzylSvpdVMcNABUonxDPCUCo0zQD',
    "g_state": '{"i_l":0}',
    "li_rm": "AQF--9-49_8nvQAAAZqibTHHJFguEjlWFPJfylXip-C-Ntz7evPei6zRvIzAkf0SaZbTzJcmYwr6WtY5EbYqd0A0AThPtQSuUQjetyTrUAtZfpzkk3ki7d5Y",
    "li_theme": "light",
    "li_theme_set": "app",
    "li_sugr": "96e59326-2816-4f83-95aa-052a94c3b490",
    "bcookie": 'v=2&67d253d6-a6e8-4765-8747-9ead163cf620',
    "timezone": "Asia/Saigon",
    "AMCVS_14215E3D5995C57C0A495C55@AdobeOrg": "1",
    "dfpfpt": "b3ebf4bcaca245e190e51ca42319199d",
    "_pxvid": "23010cfb-1397-11f1-950c-7f6137f5a050",
    "visit": "v=1&M",
    "sdui_ver": "sdui-flagship:0.1.30166+SduiFlagship0",
    "fptctx2": "",
    "liap": "true",
    "li_at": "AQEDAV_UGWUDwqUEAAABnMaYUwEAAAGc6qTXAVYADCrjsXVNBD96Nt593qY0UpzS8I-1HmLYRWUtWaPC0eUV947VbKHlALiQfJVkDow5w3c54je12eRg3Onlx_AW9RjLhxWOs7t6lpsXYRF0LxgPV5ey",
    "JSESSIONID": '"ajax:1656999207179305697"',
    "lang": "v=2&lang=vi-vn",
    "lidc": '"b=OB53:s=O:r=O:a=O:p=O:g=4186:u=10:x=1:i=1772860700:t=1772944554:v=2:sig=AQFh73TUKSzvoqanO_pApW_HjjX77AT7"',
    "UserMatchHistory": "AQKPQ_4gRIYIaAAAAZzGu341_XaBr9ovSIyGg5TXtWo7EV9kOfBbvtFUAEeSlPXJ3-uTS7iL9_8smI5mmJPGhL8KPgex6E_fGe9R1wOGhdNCXx3C5SYnkU-zej-C1ZHOGr0ADwC71D-4uxLrb6z1tDAPiLr6mvA1Kfdu7XB746A6mEEmhvQem46ElvlEhxkLcI56gXlvA9Stf-b-5Ke3weDMl9hn0HglU_D7ZN1rQFx5GGp9MjFQMt0Mu8MV2-1dynhGHUvqpIsjnQaVeEEaURopOZZydcB9w4O_EVNtkRfwS94tPsUWXdcIIbV3vpLPPOyxrXO_eku9k9t_CGCg",
    "__cf_bm": "TpOPTSvKUCnGLH8eGwyfYw26ohJ0FEeUBpMg06l6z0k-1772861397-1.0.1.1-LZ6.ZuU.AsylN2Rxb87cVWN2f59bE.wxoI96yRJdKniP9yprVClePqMSO1aI_CrVNYvhOTFVeiMAFEAnRYsGGWBcmwQbq3RrijvyL_W6pKM",
    "AMCV_14215E3D5995C57C0A495C55@AdobeOrg": "-637568504|MCIDTS|20520|MCMID|27158816828677600414853319144040392812|MCOPTOUT-1772868665s|NONE|vVersion|5.1.1",
    "_uetsid": "cf3a840019df11f1a714ddddc6f4f495",
    "_uetvid": "7b63d330139811f1bfd21357de95d556",
}

session = requests.Session()
session.headers.update(headers)
session.cookies.update(cookies)

# Test kết nối
test_url = "https://www.linkedin.com/voyager/api/voyagerJobsDashJobCards?decorationId=com.linkedin.voyager.dash.deco.jobs.search.JobSearchCardsCollection-220&count=1&q=jobSearch&query=(origin:JOBS_HOME_KEYWORD_HISTORY,keywords:IT,locationUnion:(geoId:104195383),selectedFilters:(distance:List(25.0)),spellCorrectionEnabled:true)&start=0"

print("=" * 60)
print("TEST KẾT NỐI LINKEDIN (All Cookies)")
print("=" * 60)
print(f"✓ Headers: {len(headers)} items")
print(f"✓ Cookies: {len(cookies)} items")
print()

try:
    print("Gửi request...")
    response = session.get(test_url, timeout=15, allow_redirects=False)
    print(f"Status Code: {response.status_code}")
    
    if response.status_code == 200:
        try:
            data = response.json()
            if 'data' in data:
                total_jobs = data.get('data', {}).get('paging', {}).get('total', 0)
                print(f"✓ Kết nối thành công!")
                print(f"  Included items: {len(data.get('included', []))}")
                print(f"  Tổng jobs tìm được: {total_jobs}")
            else:
                print("✗ Response không có 'data' field")
        except Exception as e:
            print(f"✗ Response không phải JSON: {e}")
    elif response.status_code in [301, 302, 303, 307, 308]:
        print(f"✗ REDIRECT {response.status_code}")
        print("  → Cookies chưa đủ hoặc hết hạn!")
    elif response.status_code in [401, 403]:
        print(f"✗ HTTP {response.status_code} - Unauthorized")
    else:
        print(f"✗ HTTP {response.status_code}")
        
except Exception as e:
    print(f"✗ Lỗi: {e}")

print("=" * 60)
# Out:
# ============================================================
# TEST KẾT NỐI LINKEDIN (All Cookies)
# ============================================================
# ✓ Headers: 19 items
# ✓ Cookies: 24 items
#
# Gửi request...
# Status Code: 200
# ✓ Kết nối thành công!
#   Included items: 8
#   Tổng jobs tìm được: 1054
# ============================================================

# %%
# Cell 3: Load keywords từ file (hoặc mặc định)
def load_keywords(filename="keywords.txt"):
    try:
        with open(filename, "r", encoding="utf-8") as f:
            keywords = [line.strip() for line in f if line.strip()]
        print(f"Đã tải {len(keywords)} từ khóa: {keywords}")
        return keywords
    except FileNotFoundError:
        print("Không tìm thấy 'keywords.txt' → dùng mặc định")
        return ["it", "software engineer", "data analyst", "developer vietnam"]

keywords_list = load_keywords()
print("\nDanh sách keywords:", keywords_list)
# Out:
# Đã tải 6 từ khóa: ['IT', 'Information Technology', 'Công nghệ thông tin', 'CNTT', 'Computer Science', 'CS']
#
# Danh sách keywords: ['IT', 'Information Technology', 'Công nghệ thông tin', 'CNTT', 'Computer Science', 'CS']

# %%
# Cell 4: Load job đã xử lý trước đó (tránh duplicate)
def load_existing_summaries():
    if not os.path.exists(SUMMARY_FILE):
        return set()
    existing_ids = set()
    with open(SUMMARY_FILE, "r", encoding="utf-8") as f:
        for i, line in enumerate(f):
            if (i + 1) % 500 == 0:
                print(f"   Loading summaries cũ: {i+1} dòng...")
            if line.strip():
                try:
                    entry = json.loads(line)
                    existing_ids.add(entry['job_id'])
                except:
                    pass
    print(f"Đã load {len(existing_ids)} job đã xử lý trước đó.")
    return existing_ids

processed_job_ids = load_existing_summaries()
seen_job_ids = processed_job_ids.copy()
# Out:
#    Loading summaries cũ: 500 dòng...
#    Loading summaries cũ: 1000 dòng...
#    Loading summaries cũ: 1500 dòng...
#    Loading summaries cũ: 2000 dòng...
#    Loading summaries cũ: 2500 dòng...
#    Loading summaries cũ: 3000 dòng...
#    Loading summaries cũ: 3500 dòng...
#    Loading summaries cũ: 4000 dòng...
#    Loading summaries cũ: 4500 dòng...
#    Loading summaries cũ: 5000 dòng...
#    Loading summaries cũ: 5500 dòng...
#    Loading summaries cũ: 6000 dòng...
#    Loading summaries cũ: 6500 dòng...
#    Loading summaries cũ: 7000 dòng...
#    Loading summaries cũ: 7500 dòng...
#    Loading summaries cũ: 8000 dòng...
#    Loading summaries cũ: 8500 dòng...
#    Loading summaries cũ: 9000 dòng...
#    Loading summaries cũ: 9500 dòng...
#    Loading summaries cũ: 10000 dòng...
#    Loading summaries cũ: 10500 dòng...
#    Loading summaries cũ: 11000 dòng...
#    Loading summaries cũ: 11500 dòng...
#    Loading summaries cũ: 12000 dòng...
#    Loading summaries cũ: 12500 dòng...
#    Loading summaries cũ: 13000 dòng...
#    Loading summaries cũ: 13500 dòng...
#    Loading summaries cũ: 14000 dòng...
#    Loading summaries cũ: 14500 dòng...
#    Loading summaries cũ: 15000 dòng...
#    Loading summaries cũ: 15500 dòng...
#    Loading summaries cũ: 16000 dòng...
#    Loading summaries cũ: 16500 dòng...
#    Loading summaries cũ: 17000 dòng...
#    Loading summaries cũ: 17500 dòng...
#    Loading summaries cũ: 18000 dòng...
#    Loading summaries cũ: 18500 dòng...
#    Loading summaries cũ: 19000 dòng...
#    Loading summaries cũ: 19500 dòng...
#    Loading summaries cũ: 20000 dòng...
#    Loading summaries cũ: 20500 dòng...
#    Loading summaries cũ: 21000 dòng...
#    Loading summaries cũ: 21500 dòng...
#    Loading summaries cũ: 22000 dòng...
#    Loading summaries cũ: 22500 dòng...
#    Loading summaries cũ: 23000 dòng...
#    Loading summaries cũ: 23500 dòng...
#    Loading summaries cũ: 24000 dòng...
#    Loading summaries cũ: 24500 dòng...
#    Loading summaries cũ: 25000 dòng...
#    Loading summaries cũ: 25500 dòng...
# Đã load 25735 job đã xử lý trước đó.

# %%
# Cell 5: Hàm fetch danh sách job (pagination)
base_url = "https://www.linkedin.com/voyager/api/voyagerJobsDashJobCards"

def fetch_job_list(keyword, seen_job_ids):
    query_string_base = (
        f"decorationId=com.linkedin.voyager.dash.deco.jobs.search.JobSearchCardsCollection-220"
        f"&count={COUNT}"
        f"&q=jobSearch"
        f"&query=(origin:JOBS_HOME_KEYWORD_HISTORY,keywords:{keyword},locationUnion:(geoId:104195383),selectedFilters:(distance:List(25.0)),spellCorrectionEnabled:true)"
        f"&start="
    )

    new_jobs = []
    start = 0
    total = None
    page = 1

    print(f"[{keyword.upper()}] Bắt đầu tìm kiếm...")

    while total is None or start < total:
        print(f"   Trang {page} (start={start})...", end=" ")
        url = f"{base_url}?{query_string_base}{start}"
        try:
            response = session.get(url, timeout=30, allow_redirects=False)
            if response.status_code != 200:
                print(f"HTTP {response.status_code}")
                break
            data = response.json()
        except Exception as e:
            print(f"Lỗi: {e}")
            break

        included = data.get('included', [])
        if total is None:
            total = data.get('data', {}).get('paging', {}).get('total', 0)
            print(f"→ Tổng: {total}")

        jobs_found = 0
        for item in included:
            if (item.get('$type') == 'com.linkedin.voyager.dash.jobs.JobPosting' and
                item.get('entityUrn', '').startswith('urn:li:fsd_jobPosting:')):
                job_id = item['entityUrn'].split(':')[-1]
                if job_id not in seen_job_ids:
                    seen_job_ids.add(job_id)
                    new_jobs.append(item)
                    jobs_found += 1

        print(f"+{jobs_found} job mới")
        if jobs_found == 0 and start > 0:
            break

        start += COUNT
        page += 1
        time.sleep(1)

    print(f"[{keyword.upper()}] Hoàn thành: +{len(new_jobs)} job mới\n")
    return new_jobs

# %%
# Cell 6: Hàm fetch chi tiết job (có retry)
def fetch_job_detail(job_id):
    url_temp = "https://www.linkedin.com/voyager/api/graphql"
    urn_raw = f"urn:li:fsd_jobPosting:{job_id}"
    urn_encoded = quote(urn_raw, safe="")
    variables = f"(jobPostingUrn:{urn_encoded})"
    query_id = "voyagerJobsDashJobPostings.891aed7916d7453a37e4bbf5f1f60de4"
    url = f"{url_temp}?variables={variables}&queryId={query_id}"

    for attempt in range(RETRY_COUNT):
        try:
            response = session.get(url, timeout=20, allow_redirects=False)
            if response.status_code != 200:
                if attempt == RETRY_COUNT - 1:
                    return None, None
                time.sleep(1)
                continue
            data = response.json()
            included = data.get('included', [])
            for item in included:
                if item.get('$type') == 'com.linkedin.voyager.dash.jobs.JobPosting':
                    return item, included
            return None, None
        except Exception:
            if attempt == RETRY_COUNT - 1:
                return None, None
            time.sleep(0.5 ** attempt)
    return None, None

# %%
# Cell 7: Hàm extract thông tin job
def extract_job_info(job_detail, included=None):
    if not job_detail:
        return None

    def resolve_urn(urn, target_type):
        if not urn or not included:
            return None
        for item in included:
            if item.get('entityUrn') == urn and item.get('$type') == target_type:
                return item
        return None

    job_id = job_detail.get('entityUrn', '').split(':')[-1]
    job_title = job_detail.get('title', '')
    company_name = job_detail.get('companyDetails', {}).get('name')

    location = None
    loc_urn = job_detail.get('*location')
    if loc_urn and isinstance(loc_urn, str):
        geo = resolve_urn(loc_urn, 'com.linkedin.voyager.dash.common.Geo')
        if geo:
            location = geo.get('defaultLocalizedName') or geo.get('abbreviatedLocalizedName')
    if not location:
        location = job_detail.get('formattedLocation')

    description = job_detail.get('description', {}).get('text', '')

    posting_date = None
    if job_detail.get('listedAt'):
        try:
            posting_date = datetime.datetime.fromtimestamp(job_detail['listedAt'] / 1000).strftime('%Y-%m-%d')
        except:
            pass

    # Các field khác tương tự...
    job_url = f"https://www.linkedin.com/jobs/view/{job_id}"

    return {
        'job_id': job_id,
        'job_title': job_title,
        'company': company_name,
        'location': location,
        'description': description,
        'posting_date': posting_date,
        'job_url': job_url,
        'crawled_at': datetime.datetime.now().isoformat(),
        # Thêm các field khác nếu cần
    }

# %%
# Cell 8: CHẠY SCRAPING CHÍNH (chạy cell này cuối cùng)

all_new_jobs = []

for idx, kw in enumerate(keywords_list, 1):
    print(f"[{idx}/{len(keywords_list)}] Từ khóa: '{kw}'")
    new_jobs = fetch_job_list(kw, seen_job_ids)
    all_new_jobs.extend(new_jobs)

if not all_new_jobs:
    print("Không có job mới nào. Kết thúc.")
else:
    print(f"\nTổng {len(all_new_jobs)} job mới cần lấy detail.\n")

    file_exists = os.path.exists(CSV_FILE)
    with open(CSV_FILE, 'a', newline='', encoding='utf-8-sig') as csvfile:
        fieldnames = ['job_id', 'job_title', 'company', 'location', 'description',
                      'posting_date', 'job_url', 'crawled_at']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        if not file_exists or os.stat(CSV_FILE).st_size == 0:
            writer.writeheader()

        success = 0
        failed = 0

        with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
            futures = {executor.submit(fetch_job_detail, job['entityUrn'].split(':')[-1]): job for job in all_new_jobs}

            processed = 0
            total = len(futures)
            for future in as_completed(futures):
                processed += 1
                job = futures[future]
                job_id = job['entityUrn'].split(':')[-1]
                title = job.get('title', 'No title')

                job_detail, included = future.result()
                source = job_detail or job
                info = extract_job_info(source, included=included)

                if info:
                    writer.writerow(info)
                    csvfile.flush()

                    # Lưu summary
                    entry = {
                        "job_id": job_id,
                        "title": job.get('title'),
                        "entityUrn": job['entityUrn'],
                        "crawled_at": datetime.datetime.now().isoformat(),
                    }
                    with open(SUMMARY_FILE, "a", encoding="utf-8") as f:
                        f.write(json.dumps(entry, ensure_ascii=False) + "\n")

                    success += 1
                    print(f"[{processed}/{total}] [OK] {job_id} - {title}")
                else:
                    failed += 1
                    print(f"[{processed}/{total}] [FAIL] {job_id} - {title}")

                time.sleep(0.25)

    print("\nHOÀN THÀNH!")
    print(f"Thành công: {success} | Fail: {failed} | File: {CSV_FILE}")
# Out:
# [1/6] Từ khóa: 'IT'
# [IT] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 1055
# +6 job mới
#    Trang 2 (start=100)... +0 job mới
# [IT] Hoàn thành: +6 job mới
#
# [2/6] Từ khóa: 'Information Technology'
# [INFORMATION TECHNOLOGY] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 206
# +3 job mới
#    Trang 2 (start=100)... +5 job mới
#    Trang 3 (start=200)... +0 job mới
# [INFORMATION TECHNOLOGY] Hoàn thành: +8 job mới
#
# [3/6] Từ khóa: 'Công nghệ thông tin'
# [CÔNG NGHỆ THÔNG TIN] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 3637
# +13 job mới
#    Trang 2 (start=100)... +15 job mới
#    Trang 3 (start=200)... +18 job mới
#    Trang 4 (start=300)... +17 job mới
#    Trang 5 (start=400)... +15 job mới
#    Trang 6 (start=500)... +17 job mới
#    Trang 7 (start=600)... +16 job mới
#    Trang 8 (start=700)... +22 job mới
#    Trang 9 (start=800)... +9 job mới
#    Trang 10 (start=900)... +12 job mới
#    Trang 11 (start=1000)... +0 job mới
# [CÔNG NGHỆ THÔNG TIN] Hoàn thành: +154 job mới
#
# [4/6] Từ khóa: 'CNTT'
# [CNTT] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 24
# +0 job mới
# [CNTT] Hoàn thành: +0 job mới
#
# [5/6] Từ khóa: 'Computer Science'
# [COMPUTER SCIENCE] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 4181
# +0 job mới
#    Trang 2 (start=100)... +1 job mới
#    Trang 3 (start=200)... +3 job mới
#    Trang 4 (start=300)... +6 job mới
#    Trang 5 (start=400)... +8 job mới
#    Trang 6 (start=500)... +4 job mới
#    Trang 7 (start=600)... +1 job mới
#    Trang 8 (start=700)... +5 job mới
#    Trang 9 (start=800)... +3 job mới
#    Trang 10 (start=900)... +9 job mới
#    Trang 11 (start=1000)... +0 job mới
# [COMPUTER SCIENCE] Hoàn thành: +40 job mới
#
# [6/6] Từ khóa: 'CS'
# [CS] Bắt đầu tìm kiếm...
#    Trang 1 (start=0)... → Tổng: 3143
# +2 job mới
#    Trang 2 (start=100)... +4 job mới
#    Trang 3 (start=200)... +4 job mới
#    Trang 4 (start=300)... +3 job mới
#    Trang 5 (start=400)... +5 job mới
#    Trang 6 (start=500)... +1 job mới
#    Trang 7 (start=600)... +1 job mới
#    Trang 8 (start=700)... +5 job mới
#    Trang 9 (start=800)... +5 job mới
#    Trang 10 (start=900)... +9 job mới
#    Trang 11 (start=1000)... +0 job mới
# [CS] Hoàn thành: +39 job mới
#
#
# Tổng 247 job mới cần lấy detail.
#
# [1/247] [OK] 4383061978 - Data Analyst (Credit Risk)
# [2/247] [OK] 4381396357 - Chuyên viên Đào tạo triển khai phần mềm (Fresher)
# [3/247] [OK] 4384219843 - Nhân Viên Ngôn ngữ Dữ liệu Tiếng Nhật
# [4/247] [OK] 4384219263 - Data Collaborator (Ưu tiên sinh viên ĐH)
# [5/247] [OK] 4383084423 - Data Annotator
# [6/247] [OK] 4383501902 - Chuyên viên An toàn thông tin (ISMS)
# [7/247] [OK] 4384222984 - Information Technology Operations Manager
# [8/247] [OK] 4363970999 - P&G LEAD GEN Commercial Data Intern
# [9/247] [OK] 4384380592 - Cán bộ Văn hóa Đoàn thể
# [10/247] [OK] 4384245034 - Chief Accountant (SAP/English/Vinh Phuc-Hanoi)
# [11/247] [OK] 4385311667 - VN - IT Staff/ IT Support / IT Helpdesk
# [12/247] [OK] 4384236162 - Purchasing Specialist (IT/Telecom)
# [13/247] [OK] 4385324104 - IT Business Analysis Senior Specialist (Chuyên viên Cấp cao Phân tích Nghiệp vụ)
# [14/247] [OK] 4382855327 - Giám Đốc Phòng Quản Lý Rủi Ro, Quy Trình và Tuân Thủ
# [15/247] [OK] 4384233218 - Cộng tác viên (Remote) chứng khoán
# [16/247] [OK] 4371129598 - [Miền Trung] Nhân viên Kinh doanh phân phối IT
# [17/247] [OK] 4384233428 - Partnership Intern
# [18/247] [OK] 4384227737 - Chuyên Viên Kế Toán Kho
# [19/247] [OK] 4384226616 - AI Engineer Internship
# [20/247] [OK] 4385325083 - Henry test resync updated
# [21/247] [OK] 4384213334 - CUSTOMER SUPPORT (Open for Freshers - WFH 2 weeks/month)
# [22/247] [OK] 4383072277 - Nhân viên Kiểm soát Chất lượng Gạo (KCS)
# [23/247] [OK] 4379411191 - International Accountant (Singapore entity)
# [24/247] [OK] 4384222764 - Android Framework Engineer
# [25/247] [OK] 4383545125 - NPI Engineer (Fresher)
# [26/247] [OK] 4383287680 - 质量工程师
# [27/247] [OK] 4384240172 - Data Entry Intern
# [28/247] [OK] 4384221989 - Kế toán (Tiếng Trung)
# [29/247] [OK] 4385306238 - Henry test case updated
# [30/247] [OK] 4383539475 - Process Engineer (Junior)
# [31/247] [OK] 4385303259 - Brand and Graphic Designer
# [32/247] [OK] 4384226646 - Giám Đốc Điều Hành Vùng Siêu Thị Nội Thất
# [33/247] [OK] 4383918813 - Junior Australia Accountant (100% Remote – Vietnam Based)
# [34/247] [OK] 4385300910 - Head of Legal - Investments
# [35/247] [OK] 4379826044 - TRƯỞNG NHÓM KẾ TOÁN TÀI SẢN & KHO
# [36/247] [OK] 4384236315 - Business Development Manager
# [37/247] [OK] 4384238244 - Chuyên Viên Kế Toán Dịch Vụ
# [38/247] [OK] 4379632541 - Thực tập sinh Tuyển dụng
# [39/247] [OK] 4384555880 - Machine Learning Engineer
# [40/247] [OK] 4384143056 - Account Manager
# [41/247] [OK] 4383510895 - Thực tập sinh Account (Lĩnh vực âm nhạc)
# [42/247] [OK] 4383288826 - [REMOTE] KOC Booking Operator (Fresher tiếng Hàn) | 9~11M
# [43/247] [OK] 4383906423 - 2D CAD Designer | $65/hr Remote
# [44/247] [OK] 4383914274 - Engineering Internship
# [45/247] [OK] 4383973374 - AI Trainer (Korean) | $11/hr Remote
# [46/247] [OK] 4384591891 - AI Trainer - Freelance Data Annotator
# [47/247] [OK] 4383940713 - Customs Clearance Intern (6-month - HCMC)
# [48/247] [OK] 4383577913 - Method Intern
# [49/247] [OK] 4383956849 - Generalist (Korean) | $11/hr Remote
# [50/247] [OK] 4380198392 - Biên dịch tiếng Anh
# [51/247] [OK] 4381549854 - Nhân viên tuyển dụng
# [52/247] [OK] 4384216939 - Game Tester (Junior/Middle)
# [53/247] [OK] 4384130840 - Cộng tác viên Vận Hành Lớp Học [Quận 7, quận 3, Bình Dương]
# [54/247] [OK] 4382791205 - Vietnamese-Speaking Data Annotator (Vietnam)
# [55/247] [OK] 4383525899 - Panda3D Game Developer- Python & C++ | Remote
# [56/247] [OK] 4383967587 - Data Annotator (Korean) | $11/hr Remote
# [57/247] [OK] 4383252768 - Remote Recruiter (Freelance)
# [58/247] [OK] 4383900734 - 3D CAD Engineer (OpenSCAD) | Remote
# [59/247] [OK] 4383238022 - Vietnam Intern
# [60/247] [OK] 4383568877 - Visualization Engineer | $65/hr Remote
# [61/247] [OK] 4383063909 - Head of Taxation Product and Business for SME Merchants
# [62/247] [OK] 4378241195 - SAT Instructors Online/Offline (Vietnamese Only)
# [63/247] [OK] 4384218294 - [REMOTE] AI Ads Creative Designer (~24M | Brand: GIGR)
# [64/247] [OK] 4384209692 - AI Specialist - Cantonese
# [65/247] [OK] 4382843662 - Brand Winnership
# [66/247] [OK] 4384226640 - Kế toán kiêm Hành chính nhân sự
# [67/247] [OK] 4384235342 - Data Entry Intern - UK Clients
# [68/247] [OK] 4383535631 - Digital Illustrator (Krita) | $65/hr Remote
# [69/247] [OK] 4384564905 - Vietnamese Audio Engineer Expert
# [70/247] [OK] 4384219988 - Influencer Marketing Coordinator
# [71/247] [OK] 4384219831 - Sales Manager (Vietnamese Speaker) - SCGJWD Logistics, Southern of Vietnam
# [72/247] [OK] 4384813256 - Trainee - Accounting & Tax Service
# [73/247] [OK] 4375219173 - Freelance Peer Reviewer, Civil Engineering, Mechanical Engineering, Computer Science
# [74/247] [OK] 4383551189 - Senior Financial Planning Analyst
# [75/247] [OK] 4382406222 - Chuyên gia, Chuyên viên cao cấp Kiến trúc ứng dụng - Solution Architect - Khối Công nghệ thông tin (HOLT.10)
# [76/247] [OK] 4381550504 - HMI UX Lead Designer
# [77/247] [OK] 4384212560 - JUNIOR BUSINESS ANALYST
# [78/247] [OK] 4385311357 - [Huawei] Solar Solution Architect
# [79/247] [OK] 4383550124 - Nhân viên
# [80/247] [OK] 4385318452 - Taste The Future MT - Manufacturing, SEA
# [81/247] [OK] 4376714273 - Solutions Consultant (Chinese speaking)
# [82/247] [OK] 4384223656 - Finance Intern – Venture Finance & Portfolio Analytics
# [83/247] [OK] 4384580469 - Kỹ Thuật Viên Vận Hành Máy Cơ Khí
# [84/247] [OK] 4378912544 - Sample cutting staff (6-month contract) / Nhân viên cắt mẫu (HĐ 6 tháng)
# [85/247] [OK] 4381420357 - Product Manager, Adtima
# [86/247] [OK] 4383517739 - Accounting Intern
# [87/247] [OK] 4384205563 - [Hanoi] Python / Java Fullstack Developer - Up to 43M VND
# [88/247] [OK] 4383534312 - [D12] Engineering Project Management Intern
# [89/247] [OK] 4378913164 - Sales Training Team Leader
# [90/247] [OK] 4378919721 - APAC Associate, Survey Delivery & Innovation - B2B Surveys
# [91/247] [OK] 4384860635 - Remote AI Quality Analyst (Vietnamese) - 62141
# [92/247] [OK] 4382753471 - Trade Marketing Freelancer
# [93/247] [OK] 4383245964 - Remote Recruiter (Freelance)
# [94/247] [OK] 4376017584 - Middle Data Engineer (Game Data)
# [95/247] [OK] 4385146159 - Nhân viên vận đơn-Hỗ trợ kinh doanh Online
# [96/247] [OK] 4383516231 - [REMOTE] Video Editor - AI (~17M | Brand: Studio Aim)
# [97/247] [OK] 4383532844 - Nhân Viên Hành chính Quản Lý Tài Sản
# [98/247] [OK] 4383585386 - Data Annotator/Data Label (Vietnamese Speaker) - Work in Dubai)
# [99/247] [OK] 4383580911 - (Fresher) Human Resources
# [100/247] [OK] 4383912187 - Nhân viên Thiết kế máy
# [101/247] [OK] 4384235133 - AP and Payment (Vietnamese Speaker) - Long Son Petrochemicals, Long Son, HCMC
# [102/247] [OK] 4384571313 - [HN, People Team] Cộng tác viên Tuyển dụng
# [103/247] [OK] 4382784888 - Deals Internship Programme (HCMC)
# [104/247] [OK] 4377744038 - Nhân viên Chất lượng mua hàng
# [105/247] [OK] 4384220551 - Full Stack - Lập trình website
# [106/247] [OK] 4383299812 - Chuyên viên Đào tạo và Phát triển
# [107/247] [OK] 4384884843 - Intern Development Apparel
# [108/247] [OK] 4384580507 - Vietnamese Script Writer Expert
# [109/247] [OK] 4382788673 - Deals Internship Programme (HAN)
# [110/247] [OK] 4381844702 - Chuyên viên cao cấp/ Chuyên viên Tác nghiệp dịch vụ
# [111/247] [OK] 4383539489 - Chuyên viên Tuyển dụng & Ban Đại học
# [112/247] [OK] 4384221257 - (Cobi Tower 1 - HCMC) Java Developer
# [113/247] [OK] 4370945715 - Thực Tập Sinh Tuyển Dụng
# [114/247] [OK] 4380060516 - CTV chứng khoán
# [115/247] [OK] 4384202710 - Business Development Intern
# [116/247] [OK] 4377725664 - Nhân viên Thiết kế khuôn
# [117/247] [OK] 4373235342 - CTV Phỏng vấn tiếng Anh Online
# [118/247] [OK] 4383292573 - [REMOTE] Vận hành KOC Booking (Tiếng Hàn | Fresher)
# [119/247] [OK] 4383211364 - Cocos2d-x Game Engine Developer (C++) | Remote
# [120/247] [OK] 4381549852 - Chuyên viên Tuyển dụng
# [121/247] [OK] 4384220226 - Cộng Tác Viên Chứng Khoán - REMOTE
# [122/247] [OK] 4382299409 - Chuyên Viên Thiết Kế 2D | VPĐH (TPHCM)
# [123/247] [OK] 4383931999 - Intern at Order Management Solutions Department (6-month - HCMC)
# [124/247] [OK] 4384303971 - Kỹ sư chính Kiểm soát Chất lượng Mạng & Chẩn đoán
# [125/247] [OK] 4383292919 - (Junior/Middle) Software Tester (Both Automation & Manual)
# [126/247] [OK] 4380193458 - Thực tập sinh Quản lý kênh Youtube fulltime
# [127/247] [OK] 4383532331 - QA Engineer (Intern Level, Korean Speaking) - Hanoi
# [128/247] [OK] 4383026951 - HR IT Freelancer (Web3 Recruitment)
# [129/247] [OK] 4384891503 - Sales Onboarding Intern
# [130/247] [OK] 4382821947 - Chuyên viên kế toán tổng hợp
# [131/247] [OK] 4382887447 - [Freelance/Remote] English → Vietnamese Translator & Reviewer (Documents & Video)
# [132/247] [OK] 4384235202 - [REMOTE] 3D Motion Artist (Nhân vật / Anime, Vtuber) (~24M | Brand: Good Gang Labs)
# [133/247] [OK] 4383957337 - Architectural Designer - Rhino3D | $65/hr Remote
# [134/247] [OK] 4385324178 - Taste The Future MT - Human Resources, SEA
# [135/247] [OK] 4383216821 - Cộng tác viên Tuyển dụng Hà Nội
# [136/247] [OK] 4381950405 - Chuyên viên Nhân sự và Tuyển Dụng
# [137/247] [OK] 4384216458 - [REMOTE] TikTok Content Creator (~12M | Brand: AROOM)
# [138/247] [OK] 4384570186 - Thực Tập Sinh Tuyển Dụng (Internship) - Nhận việc ngay
# [139/247] [OK] 4383903940 - 2D CAD Specialist | Remote
# [140/247] [OK] 4383545215 - Research Student (AI & Cybersecurity) Recruitment
# [141/247] [OK] 4385190451 - Local Product Engineer
# [142/247] [OK] 4380673733 - Hành Chính Nhân Sự Tổng Hợp
# [143/247] [OK] 4383984658 - Online English Teacher for secondary student
# [144/247] [OK] 4383039080 - P&G LEAD GEN Process Engineer Intern
# [145/247] [OK] 4383500699 - Game Designer (25M, Vietnamese)
# [146/247] [OK] 4383999953 - Marketing Executive - NIVEA brand
# [147/247] [OK] 4383553150 - Operations Intern
# [148/247] [OK] 4383533903 - Business Development Executive (Fresher/Junior)
# [149/247] [OK] 4384579463 - Strategic Planning Intern
# [150/247] [OK] 4384558629 - Software QA Engineer
# [151/247] [OK] 4380073997 - UI/UX Design Intern
# [152/247] [OK] 4383501605 - Front-end Developer (Cocos)
# [153/247] [OK] 4378204276 - Chuyên Viên Tài Chính - Nguồn Vốn
# [154/247] [OK] 4384892752 -  Software Engineer – Creative Software (Remote)
# [155/247] [OK] 4385319557 - Technical Intern, Software Test Engineer
# [156/247] [OK] 4383503962 - Thực tập sinh Phát triển Kinh doanh
# [157/247] [OK] 4384532661 - Education Growth Lead, Vietnam
# [158/247] [OK] 4383550160 - Social Media Manager | Remote
# [159/247] [OK] 4383555191 - E-commerce Business Analyst
# [160/247] [OK] 4381542944 - Nhân viên Triển khai Phần mềm (Fresher)
# [161/247] [OK] 4384224244 - Associate, Self-Serve Platform Growth
# [162/247] [OK] 4384873751 - Software Engineer (Remote)
# [163/247] [OK] 4370842676 - Chuyên viên Truyền thông tiếp thị
# [164/247] [OK] 4383526938 - Trưởng nhóm tuyển dụng/chuyên viên tuyển dụng
# [165/247] [OK] 4384578741 - Software Developer (Python, ML/AI)
# [166/247] [OK] 4377105423 - Russian Voice Actor - Freelance AI Trainer Project
# [167/247] [OK] 4383544401 - Mechanical Engineering Intern
# [168/247] [OK] 4383552291 - Specialist, Account Management - GrabFood
# [169/247] [OK] 4385308872 - Lean & EHS Internship
# [170/247] [OK] 4380157679 - Software Engineer II (Viralsweep)
# [171/247] [OK] 4385316173 - [Huawei] Solar Solution Architect
# [172/247] [OK] 4384225406 - Salesforce Developer (Consulting)
# [173/247] [OK] 4379985735 - Engineering Technician
# [174/247] [OK] 4384236192 - Senior Product Designer
# [175/247] [OK] 4385324179 - Taste The Future MT - CS&L, SEA
# [176/247] [OK] 4377852635 - Medical Representative (Ho Chi Minh) – 6-month contract
# [177/247] [OK] 4384225149 - Manager/ Senior Manager - Credit Risk Consulting
# [178/247] [OK] 4376056103 - Content Marketing Manager
# [179/247] [OK] 4383007000 - Teaching Assistant, Computing Technologies
# [180/247] [OK] 4385302422 - Customer Service Intern (all genders)
# [181/247] [OK] 4384239047 - Senior Infrastructure Risk Executive
# [182/247] [OK] 4385198417 - Technical Intern, Platform Validation Engineer
# [183/247] [OK] 4384887169 - Software Engineer (Python) - Remote
# [184/247] [OK] 4383555287 - Python Developer
# [185/247] [OK] 4385324308 - Trade Operation officer (6 months contract), Technology & Operations, DBS Vietnam HCMC
# [186/247] [OK] 4383954714 - Audio Engineer - Ardour | $80/hr Remote
# [187/247] [OK] 4383906271 - Audio Engineer | $55/hr Remote
# [188/247] [OK] 4383915869 - Biomedical Engineer (Imaging) | Remote
# [189/247] [OK] 4384210667 - AI Analyst
# [190/247] [OK] 4384877661 - Prompt Engineering Specialist
# [191/247] [OK] 4382789796 - AI Language Contributor (Asian Languages)
# [192/247] [OK] 4384853375 - Software Engineer – AI Agent Systems (Backend focused)
# [193/247] [OK] 4384850458 - Chatbot Developer
# [194/247] [OK] 4384817002 - Principal AI Engineer (Python, Machine Learning, NLP)
# [195/247] [OK] 4383963530 - Developer Associate-Procurement
# [196/247] [OK] 4384226092 - Data Analyst
# [197/247] [OK] 4385323007 - Data Analyst (Mobile Game)
# [198/247] [OK] 4382763251 - Backend Engineer (Python/Azure)
# [199/247] [OK] 4383545135 - [Ha Noi] Fresher/Junior Business Analyst
# [200/247] [OK] 4385327165 - Technical Intern, Platform Validation Engineer
# [201/247] [OK] 4385129329 - Remote Recruiter (Freelance)
# [202/247] [OK] 4383526926 - [XNOQuant] Quantitative Trader - HCM
# [203/247] [OK] 4374935127 - Video Editor | $65/hr Remote
# [204/247] [OK] 4384869255 - Remote AI Quality Analyst (Vietnamese) - 62141
# [205/247] [OK] 4383527814 - Website Administrator
# [206/247] [OK] 4384822000 - Freelance Annotator (English) - AI Trainer
# [207/247] [OK] 4383500481 - Admin Intern
# [208/247] [OK] 4380660356 - Securities Investment Collaborator – Remote
# [209/247] [OK] 4384204666 - Sales Support Collaborator
# [210/247] [OK] 4378304866 - Key Account Executive
# [211/247] [OK] 4384238368 - Chuyên viên Xuất Nhập Khẩu
# [212/247] [OK] 4384597435 - [Tan Phu] Invoicing Intern - Contact 6 months with allowance
# [213/247] [OK] 4383078211 - Early Careers - Field Operations
# [214/247] [OK] 4383552312 - Receptionist
# [215/247] [OK] 4385320327 - Inside Sales Representatives
# [216/247] [OK] 4383919450 - Customer Partner Representative
# [217/247] [OK] 4384562990 - Sunda Language Specialist - Freelance AI Trainer Project
# [218/247] [OK] 4376788663 - Customs Clearance Intern (6-month - HCMC)
# [219/247] [OK] 4383293723 - Global Network Expansion & After-Sales Operations Manager (Working Abroad)
# [220/247] [OK] 4384213536 - Liabilities Accountant
# [221/247] [OK] 4382276874 - Junior Sales Specialist (18M - 25M) - Open for Fresher
# [222/247] [OK] 4379791799 - APAC Graduate Program - Leadership Experience and Accelerated Development (LEAD) - Operations
# [223/247] [OK] 4384223370 - Analog Design Engineer
# [224/247] [OK] 4383533575 - AWS Solutions Architect
# [225/247] [OK] 4383489637 - Plumbing Supervisor
# [226/247] [OK] 4384210767 - Field Sales Intern
# [227/247] [OK] 4379613925 - Intern at Ocean Freight Department
# [228/247] [OK] 4385133272 - Thực tập sinh Financial Trading Part-time
# [229/247] [OK] 4382343629 - Language Data Quality Reviewer - Entry Level (Foundational / L1) | (German)
# [230/247] [OK] 4383585468 - Fresher Human Resources
# [231/247] [OK] 4384206546 - Senior Executive, Route Revenue Analyst (Vietnamese Relocated To Malaysia)
# [232/247] [OK] 4383517924 - DOCUMENTATION INTERN/TRAINEE
# [233/247] [OK] 4383514904 - Nhân viên Điều Vận Mảng Dược Phẩm
# [234/247] [OK] 4384202627 - Data Entry Specialist - Không yêu cầu kinh nghiệm
# [235/247] [OK] 4384579462 - Social Intern
# [236/247] [OK] 4383021250 - Sales Onboarding Intern
# [237/247] [OK] 4381561742 - HR Intern (L&D Focus)
# [238/247] [OK] 4384142580 - Thực tập sinh Phát triển kinh doanh (Business Development Internship)
# [239/247] [OK] 4379279134 - NHÂN VIÊN TƯ VẤN FULL-TIME KÊNH CHAT/ONLINE
# [240/247] [OK] 4383506032 - Recruiting Operations Intern
# [241/247] [OK] 4384529665 - Finance Analyst (Fixed term contingent)
# [242/247] [OK] 4376758380 - Officer, Data Translator (40001501)
# [243/247] [OK] 4381555947 - Thực Tập Sinh Thanh Toán Và Tài Trợ Thương Mại (Xuất Nhập Khẩu)
# [244/247] [OK] 4383231083 - E-commerce Specialist
# [245/247] [OK] 4382270982 - Applied Career Research & Resources Associate
# [246/247] [OK] 4380071920 - Local Logistic
# [247/247] [OK] 4366080254 - Vietnam - 2026 Voyage Program - Rooms Operations
#
# HOÀN THÀNH!
# Thành công: 247 | Fail: 0 | File: linkedin_jobs_vietnam_it_full.csv
